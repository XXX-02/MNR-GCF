# %%
# %load main.py
import world
import utils
from world import cprint
import torch
import numpy as np
from tensorboardX import SummaryWriter
import time
import Procedure
from os.path import join
# ==============================
utils.set_seed(world.seed)
print(">>SEED:", world.seed)
# ==============================
import register
from register import dataset

Recmodel = register.MODELS[world.model_name](world.config, dataset)
Recmodel = Recmodel.to(world.device)
bpr = utils.BPRLoss(Recmodel, world.config)

weight_file = utils.getFileName()
print(f"load and save to {weight_file}")
if world.LOAD:
    try:
        Recmodel.load_state_dict(torch.load(weight_file,map_location=torch.device('cpu')))
        world.cprint(f"loaded model weights from {weight_file}")
    except FileNotFoundError:
        print(f"{weight_file} not exists, start from beginning")
Neg_k = 1

# init tensorboard
if world.tensorboard:
    w : SummaryWriter = SummaryWriter(
                                    join(world.BOARD_PATH, time.strftime("%m-%d-%Hh%Mm%Ss-") + "-" + world.comment)
                                    )
else:
    w = None
    world.cprint("not enable tensorflowboard")

try:
    for epoch in range(world.TRAIN_epochs):
        start = time.time()
        if epoch %10 == 0:
            cprint("[TEST]")
            Procedure.Test(dataset, Recmodel, epoch, w, world.config['multicore'])
        output_information = Procedure.BPR_train_original(dataset, Recmodel, bpr, epoch, neg_k=Neg_k,w=w)
        print(f'EPOCH[{epoch+1}/{world.TRAIN_epochs}] {output_information}')
        torch.save(Recmodel.state_dict(), weight_file)
finally:
    if world.tensorboard:
        w.close()
# Out:
# >>SEED: 2020
# loading [../../LightGCN-PyTorch-master/data/sport]
# 48919 interactions for training
# 18784 interactions for testing
# sport Sparsity : 0.0008494123180355893
# sport is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 5,
#  'lr': 0.001,
#  'multicore': 1,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 24
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded heterogeneous graph ...
# don't split the matrix
# loading adjacency matrix
# successfully loaded homogeneous graph ...
# don't split the matrix
# loading degree weight
# successfully loaded heterogeneous degree weight ...
# lgn is already to go(dropout:0)
# load and save to /home/user1/Larry/FGCF/runs/code/checkpoints/lgn-sport-5-64.pth.tar
# [TEST]
# {'precision': array([0.00018355]), 'recall': array([0.00172633]), 'ndcg': array([0.00075736])}
# EPOCH[1/1000] loss0.686-|Sample:0.02|
# EPOCH[2/1000] loss0.683-|Sample:0.01|
# EPOCH[3/1000] loss0.678-|Sample:0.02|
# EPOCH[4/1000] loss0.667-|Sample:0.01|
# EPOCH[5/1000] loss0.647-|Sample:0.01|
# EPOCH[6/1000] loss0.616-|Sample:0.02|
# EPOCH[7/1000] loss0.577-|Sample:0.01|
# EPOCH[8/1000] loss0.536-|Sample:0.01|
# EPOCH[9/1000] loss0.499-|Sample:0.01|
# EPOCH[10/1000] loss0.465-|Sample:0.01|
# [TEST]
# {'precision': array([0.00372614]), 'recall': array([0.03100385]), 'ndcg': array([0.01857881])}
# EPOCH[11/1000] loss0.437-|Sample:0.02|
# EPOCH[12/1000] loss0.410-|Sample:0.01|
# EPOCH[13/1000] loss0.390-|Sample:0.02|
# EPOCH[14/1000] loss0.377-|Sample:0.01|
# EPOCH[15/1000] loss0.360-|Sample:0.02|
# EPOCH[16/1000] loss0.344-|Sample:0.01|
# EPOCH[17/1000] loss0.335-|Sample:0.02|
# EPOCH[18/1000] loss0.326-|Sample:0.01|
# EPOCH[19/1000] loss0.315-|Sample:0.02|
# EPOCH[20/1000] loss0.309-|Sample:0.01|
# [TEST]
# {'precision': array([0.00412384]), 'recall': array([0.03392828]), 'ndcg': array([0.02003111])}
# EPOCH[21/1000] loss0.301-|Sample:0.02|
# EPOCH[22/1000] loss0.292-|Sample:0.02|
# EPOCH[23/1000] loss0.287-|Sample:0.01|
# EPOCH[24/1000] loss0.279-|Sample:0.01|
# EPOCH[25/1000] loss0.272-|Sample:0.02|
# EPOCH[26/1000] loss0.268-|Sample:0.01|
# EPOCH[27/1000] loss0.260-|Sample:0.02|
# EPOCH[28/1000] loss0.258-|Sample:0.01|
# EPOCH[29/1000] loss0.251-|Sample:0.01|
# EPOCH[30/1000] loss0.247-|Sample:0.01|
# [TEST]
# {'precision': array([0.00449094]), 'recall': array([0.03686917]), 'ndcg': array([0.02111806])}
# EPOCH[31/1000] loss0.243-|Sample:0.02|
# EPOCH[32/1000] loss0.238-|Sample:0.02|
# EPOCH[33/1000] loss0.230-|Sample:0.02|
# EPOCH[34/1000] loss0.229-|Sample:0.01|
# EPOCH[35/1000] loss0.223-|Sample:0.01|
# EPOCH[36/1000] loss0.218-|Sample:0.01|
# EPOCH[37/1000] loss0.218-|Sample:0.02|
# EPOCH[38/1000] loss0.212-|Sample:0.02|
# EPOCH[39/1000] loss0.207-|Sample:0.01|
# EPOCH[40/1000] loss0.203-|Sample:0.02|
# [TEST]
# {'precision': array([0.00482746]), 'recall': array([0.04039102]), 'ndcg': array([0.02248954])}
# EPOCH[41/1000] loss0.205-|Sample:0.02|
# EPOCH[42/1000] loss0.204-|Sample:0.01|
# EPOCH[43/1000] loss0.196-|Sample:0.01|
# EPOCH[44/1000] loss0.193-|Sample:0.02|
# EPOCH[45/1000] loss0.188-|Sample:0.01|
# EPOCH[46/1000] loss0.188-|Sample:0.01|
# EPOCH[47/1000] loss0.183-|Sample:0.01|
# EPOCH[48/1000] loss0.180-|Sample:0.02|
# EPOCH[49/1000] loss0.178-|Sample:0.01|
# EPOCH[50/1000] loss0.173-|Sample:0.02|
# [TEST]
# {'precision': array([0.0049743]), 'recall': array([0.04185212]), 'ndcg': array([0.0231126])}
# EPOCH[51/1000] loss0.173-|Sample:0.02|
# EPOCH[52/1000] loss0.170-|Sample:0.01|
# EPOCH[53/1000] loss0.169-|Sample:0.02|
# EPOCH[54/1000] loss0.165-|Sample:0.02|
# EPOCH[55/1000] loss0.165-|Sample:0.01|
# EPOCH[56/1000] loss0.162-|Sample:0.01|
# EPOCH[57/1000] loss0.159-|Sample:0.01|
# EPOCH[58/1000] loss0.156-|Sample:0.02|
# EPOCH[59/1000] loss0.154-|Sample:0.01|
# EPOCH[60/1000] loss0.152-|Sample:0.01|
# [TEST]
# {'precision': array([0.00499266]), 'recall': array([0.04224211]), 'ndcg': array([0.02343989])}
# EPOCH[61/1000] loss0.148-|Sample:0.02|
# EPOCH[62/1000] loss0.149-|Sample:0.02|
# EPOCH[63/1000] loss0.149-|Sample:0.01|
# EPOCH[64/1000] loss0.147-|Sample:0.01|
# EPOCH[65/1000] loss0.144-|Sample:0.01|
# EPOCH[66/1000] loss0.141-|Sample:0.01|
# EPOCH[67/1000] loss0.142-|Sample:0.01|
# EPOCH[68/1000] loss0.138-|Sample:0.02|
# EPOCH[69/1000] loss0.141-|Sample:0.01|
# EPOCH[70/1000] loss0.135-|Sample:0.01|
# [TEST]
# {'precision': array([0.00512726]), 'recall': array([0.04352871]), 'ndcg': array([0.02407084])}
# EPOCH[71/1000] loss0.132-|Sample:0.02|
# EPOCH[72/1000] loss0.134-|Sample:0.02|
# EPOCH[73/1000] loss0.132-|Sample:0.01|
# EPOCH[74/1000] loss0.129-|Sample:0.01|
# EPOCH[75/1000] loss0.132-|Sample:0.01|
# EPOCH[76/1000] loss0.127-|Sample:0.01|
# EPOCH[77/1000] loss0.127-|Sample:0.01|
# EPOCH[78/1000] loss0.122-|Sample:0.02|
# EPOCH[79/1000] loss0.120-|Sample:0.01|
# EPOCH[80/1000] loss0.123-|Sample:0.01|
# [TEST]
# {'precision': array([0.00512115]), 'recall': array([0.04371416]), 'ndcg': array([0.02421696])}
# EPOCH[81/1000] loss0.117-|Sample:0.02|
# EPOCH[82/1000] loss0.117-|Sample:0.01|
# EPOCH[83/1000] loss0.116-|Sample:0.01|
# EPOCH[84/1000] loss0.113-|Sample:0.01|
# EPOCH[85/1000] loss0.112-|Sample:0.02|
# EPOCH[86/1000] loss0.113-|Sample:0.01|
# EPOCH[87/1000] loss0.112-|Sample:0.02|
# EPOCH[88/1000] loss0.109-|Sample:0.01|
# EPOCH[89/1000] loss0.112-|Sample:0.01|
# EPOCH[90/1000] loss0.109-|Sample:0.01|
# [TEST]
# {'precision': array([0.00522516]), 'recall': array([0.04485563]), 'ndcg': array([0.02466504])}
# EPOCH[91/1000] loss0.105-|Sample:0.02|
# EPOCH[92/1000] loss0.105-|Sample:0.01|
# EPOCH[93/1000] loss0.104-|Sample:0.01|
# EPOCH[94/1000] loss0.103-|Sample:0.02|
# EPOCH[95/1000] loss0.101-|Sample:0.02|
# EPOCH[96/1000] loss0.102-|Sample:0.01|
# EPOCH[97/1000] loss0.101-|Sample:0.02|
# EPOCH[98/1000] loss0.099-|Sample:0.01|
# EPOCH[99/1000] loss0.098-|Sample:0.01|
# EPOCH[100/1000] loss0.100-|Sample:0.02|
# [TEST]
# {'precision': array([0.00531082]), 'recall': array([0.04506224]), 'ndcg': array([0.02502534])}
# EPOCH[101/1000] loss0.097-|Sample:0.02|
# EPOCH[102/1000] loss0.098-|Sample:0.01|
# EPOCH[103/1000] loss0.095-|Sample:0.01|
# EPOCH[104/1000] loss0.093-|Sample:0.02|
# EPOCH[105/1000] loss0.095-|Sample:0.01|
# EPOCH[106/1000] loss0.091-|Sample:0.01|
# EPOCH[107/1000] loss0.092-|Sample:0.01|
# EPOCH[108/1000] loss0.092-|Sample:0.01|
# EPOCH[109/1000] loss0.089-|Sample:0.01|
# EPOCH[110/1000] loss0.088-|Sample:0.01|
# [TEST]
# {'precision': array([0.00529246]), 'recall': array([0.04487991]), 'ndcg': array([0.02507231])}
# EPOCH[111/1000] loss0.088-|Sample:0.02|
# EPOCH[112/1000] loss0.086-|Sample:0.01|
# EPOCH[113/1000] loss0.088-|Sample:0.01|
# EPOCH[114/1000] loss0.087-|Sample:0.02|
# EPOCH[115/1000] loss0.084-|Sample:0.01|
# EPOCH[116/1000] loss0.086-|Sample:0.02|
# EPOCH[117/1000] loss0.086-|Sample:0.01|
# EPOCH[118/1000] loss0.082-|Sample:0.02|
# EPOCH[119/1000] loss0.083-|Sample:0.01|
# EPOCH[120/1000] loss0.081-|Sample:0.02|
# [TEST]
# {'precision': array([0.00532917]), 'recall': array([0.04514402]), 'ndcg': array([0.02519418])}
# EPOCH[121/1000] loss0.078-|Sample:0.02|
# EPOCH[122/1000] loss0.080-|Sample:0.01|
# EPOCH[123/1000] loss0.078-|Sample:0.01|
# EPOCH[124/1000] loss0.080-|Sample:0.01|
# EPOCH[125/1000] loss0.076-|Sample:0.01|
# EPOCH[126/1000] loss0.078-|Sample:0.01|
# EPOCH[127/1000] loss0.075-|Sample:0.02|
# EPOCH[128/1000] loss0.078-|Sample:0.01|
# EPOCH[129/1000] loss0.074-|Sample:0.02|
# EPOCH[130/1000] loss0.075-|Sample:0.01|
# [TEST]
# {'precision': array([0.00529858]), 'recall': array([0.04460881]), 'ndcg': array([0.0251783])}
# EPOCH[131/1000] loss0.075-|Sample:0.02|
# EPOCH[132/1000] loss0.072-|Sample:0.02|
# EPOCH[133/1000] loss0.072-|Sample:0.02|
# EPOCH[134/1000] loss0.071-|Sample:0.02|
# EPOCH[135/1000] loss0.071-|Sample:0.02|
# EPOCH[136/1000] loss0.073-|Sample:0.01|
# EPOCH[137/1000] loss0.069-|Sample:0.01|
# EPOCH[138/1000] loss0.069-|Sample:0.01|
# EPOCH[139/1000] loss0.067-|Sample:0.01|
# EPOCH[140/1000] loss0.068-|Sample:0.02|
# [TEST]
# {'precision': array([0.00535977]), 'recall': array([0.04522988]), 'ndcg': array([0.02533429])}
# EPOCH[141/1000] loss0.068-|Sample:0.02|
# EPOCH[142/1000] loss0.067-|Sample:0.02|
# EPOCH[143/1000] loss0.067-|Sample:0.02|
# EPOCH[144/1000] loss0.067-|Sample:0.01|
# EPOCH[145/1000] loss0.064-|Sample:0.02|
# EPOCH[146/1000] loss0.064-|Sample:0.01|
# EPOCH[147/1000] loss0.064-|Sample:0.01|
# EPOCH[148/1000] loss0.065-|Sample:0.02|
# EPOCH[149/1000] loss0.063-|Sample:0.01|
# EPOCH[150/1000] loss0.064-|Sample:0.01|
# [TEST]
# {'precision': array([0.00528634]), 'recall': array([0.0447848]), 'ndcg': array([0.02527418])}
# EPOCH[151/1000] loss0.063-|Sample:0.02|
# EPOCH[152/1000] loss0.062-|Sample:0.01|
# EPOCH[153/1000] loss0.063-|Sample:0.02|
# EPOCH[154/1000] loss0.061-|Sample:0.01|
# EPOCH[155/1000] loss0.058-|Sample:0.02|
# EPOCH[156/1000] loss0.059-|Sample:0.01|
# EPOCH[157/1000] loss0.058-|Sample:0.01|
# EPOCH[158/1000] loss0.057-|Sample:0.01|
# EPOCH[159/1000] loss0.059-|Sample:0.01|
# EPOCH[160/1000] loss0.059-|Sample:0.01|
# [TEST]
# {'precision': array([0.00526799]), 'recall': array([0.04482009]), 'ndcg': array([0.02533354])}
# EPOCH[161/1000] loss0.058-|Sample:0.02|
# EPOCH[162/1000] loss0.057-|Sample:0.01|
# EPOCH[163/1000] loss0.057-|Sample:0.01|
# EPOCH[164/1000] loss0.055-|Sample:0.01|
# EPOCH[165/1000] loss0.055-|Sample:0.01|
# EPOCH[166/1000] loss0.058-|Sample:0.02|
# EPOCH[167/1000] loss0.056-|Sample:0.01|
# EPOCH[168/1000] loss0.054-|Sample:0.01|
# EPOCH[169/1000] loss0.054-|Sample:0.02|
# EPOCH[170/1000] loss0.054-|Sample:0.01|
# [TEST]
# {'precision': array([0.0053047]), 'recall': array([0.04500452]), 'ndcg': array([0.02531921])}
# EPOCH[171/1000] loss0.053-|Sample:0.02|
# EPOCH[172/1000] loss0.054-|Sample:0.01|
# EPOCH[173/1000] loss0.054-|Sample:0.02|
# EPOCH[174/1000] loss0.053-|Sample:0.01|
# EPOCH[175/1000] loss0.051-|Sample:0.01|
# EPOCH[176/1000] loss0.052-|Sample:0.01|
# EPOCH[177/1000] loss0.051-|Sample:0.01|
# EPOCH[178/1000] loss0.052-|Sample:0.02|
# EPOCH[179/1000] loss0.049-|Sample:0.01|
# EPOCH[180/1000] loss0.050-|Sample:0.01|
# [TEST]
# {'precision': array([0.00526187]), 'recall': array([0.04445478]), 'ndcg': array([0.02508377])}
# EPOCH[181/1000] loss0.050-|Sample:0.02|
# EPOCH[182/1000] loss0.051-|Sample:0.02|
# EPOCH[183/1000] loss0.049-|Sample:0.01|
# EPOCH[184/1000] loss0.049-|Sample:0.02|
# EPOCH[185/1000] loss0.048-|Sample:0.01|
# EPOCH[186/1000] loss0.047-|Sample:0.01|
# EPOCH[187/1000] loss0.048-|Sample:0.02|
# EPOCH[188/1000] loss0.050-|Sample:0.01|
# EPOCH[189/1000] loss0.048-|Sample:0.01|
# EPOCH[190/1000] loss0.047-|Sample:0.01|
# [TEST]
# {'precision': array([0.00532305]), 'recall': array([0.04527515]), 'ndcg': array([0.02545937])}
# EPOCH[191/1000] loss0.048-|Sample:0.02|
# EPOCH[192/1000] loss0.046-|Sample:0.01|
# EPOCH[193/1000] loss0.046-|Sample:0.01|
# EPOCH[194/1000] loss0.045-|Sample:0.01|
# EPOCH[195/1000] loss0.046-|Sample:0.02|
# EPOCH[196/1000] loss0.045-|Sample:0.01|
# EPOCH[197/1000] loss0.044-|Sample:0.02|
# EPOCH[198/1000] loss0.043-|Sample:0.01|
# EPOCH[199/1000] loss0.044-|Sample:0.01|
# EPOCH[200/1000] loss0.042-|Sample:0.01|
# [TEST]
# {'precision': array([0.00529246]), 'recall': array([0.04524028]), 'ndcg': array([0.0252848])}
# EPOCH[201/1000] loss0.043-|Sample:0.02|
# EPOCH[202/1000] loss0.043-|Sample:0.02|
# EPOCH[203/1000] loss0.044-|Sample:0.01|
# EPOCH[204/1000] loss0.041-|Sample:0.02|
# EPOCH[205/1000] loss0.042-|Sample:0.01|
# EPOCH[206/1000] loss0.042-|Sample:0.02|
# EPOCH[207/1000] loss0.042-|Sample:0.01|
# EPOCH[208/1000] loss0.041-|Sample:0.02|
# EPOCH[209/1000] loss0.041-|Sample:0.01|
# EPOCH[210/1000] loss0.042-|Sample:0.01|
# [TEST]
# {'precision': array([0.00527411]), 'recall': array([0.04530608]), 'ndcg': array([0.02521812])}
# EPOCH[211/1000] loss0.041-|Sample:0.02|
# EPOCH[212/1000] loss0.041-|Sample:0.01|
# EPOCH[213/1000] loss0.042-|Sample:0.02|
# EPOCH[214/1000] loss0.039-|Sample:0.01|
# EPOCH[215/1000] loss0.039-|Sample:0.02|
# EPOCH[216/1000] loss0.040-|Sample:0.01|
# EPOCH[217/1000] loss0.040-|Sample:0.02|
# EPOCH[218/1000] loss0.038-|Sample:0.02|
# EPOCH[219/1000] loss0.038-|Sample:0.01|
# EPOCH[220/1000] loss0.039-|Sample:0.02|
# [TEST]
# {'precision': array([0.00527411]), 'recall': array([0.04552581]), 'ndcg': array([0.02525733])}
# EPOCH[221/1000] loss0.038-|Sample:0.02|
# EPOCH[222/1000] loss0.039-|Sample:0.01|
# EPOCH[223/1000] loss0.038-|Sample:0.01|
# EPOCH[224/1000] loss0.037-|Sample:0.01|
# EPOCH[225/1000] loss0.037-|Sample:0.01|
# EPOCH[226/1000] loss0.037-|Sample:0.02|
# EPOCH[227/1000] loss0.038-|Sample:0.01|
# EPOCH[228/1000] loss0.037-|Sample:0.02|
# EPOCH[229/1000] loss0.035-|Sample:0.01|
# EPOCH[230/1000] loss0.036-|Sample:0.01|
# [TEST]
# {'precision': array([0.00523128]), 'recall': array([0.0453]), 'ndcg': array([0.02517727])}
# EPOCH[231/1000] loss0.037-|Sample:0.02|
# EPOCH[232/1000] loss0.036-|Sample:0.01|
# EPOCH[233/1000] loss0.034-|Sample:0.01|
# EPOCH[234/1000] loss0.036-|Sample:0.02|
# EPOCH[235/1000] loss0.035-|Sample:0.02|
# EPOCH[236/1000] loss0.034-|Sample:0.01|
# EPOCH[237/1000] loss0.034-|Sample:0.01|
# EPOCH[238/1000] loss0.035-|Sample:0.01|
# EPOCH[239/1000] loss0.036-|Sample:0.02|
# EPOCH[240/1000] loss0.033-|Sample:0.01|
# [TEST]
# {'precision': array([0.00524963]), 'recall': array([0.04545079]), 'ndcg': array([0.02530907])}
# EPOCH[241/1000] loss0.035-|Sample:0.02|
# EPOCH[242/1000] loss0.034-|Sample:0.01|
# EPOCH[243/1000] loss0.033-|Sample:0.01|
# EPOCH[244/1000] loss0.034-|Sample:0.02|
# EPOCH[245/1000] loss0.034-|Sample:0.01|
# EPOCH[246/1000] loss0.032-|Sample:0.01|
# EPOCH[247/1000] loss0.034-|Sample:0.01|
# EPOCH[248/1000] loss0.032-|Sample:0.01|
# EPOCH[249/1000] loss0.031-|Sample:0.01|
# EPOCH[250/1000] loss0.032-|Sample:0.02|
# [TEST]
# {'precision': array([0.00524963]), 'recall': array([0.04550396]), 'ndcg': array([0.02525711])}
# EPOCH[251/1000] loss0.032-|Sample:0.02|
# EPOCH[252/1000] loss0.032-|Sample:0.01|
# EPOCH[253/1000] loss0.033-|Sample:0.02|
# EPOCH[254/1000] loss0.032-|Sample:0.02|
# EPOCH[255/1000] loss0.032-|Sample:0.01|
# EPOCH[256/1000] loss0.031-|Sample:0.01|
# EPOCH[257/1000] loss0.030-|Sample:0.01|
# EPOCH[258/1000] loss0.031-|Sample:0.02|
# EPOCH[259/1000] loss0.031-|Sample:0.01|
# EPOCH[260/1000] loss0.031-|Sample:0.01|
# [TEST]
# {'precision': array([0.00521904]), 'recall': array([0.04500055]), 'ndcg': array([0.02515287])}
# EPOCH[261/1000] loss0.030-|Sample:0.02|
# EPOCH[262/1000] loss0.029-|Sample:0.01|
# EPOCH[263/1000] loss0.030-|Sample:0.01|
# EPOCH[264/1000] loss0.030-|Sample:0.01|
# EPOCH[265/1000] loss0.029-|Sample:0.01|
# EPOCH[266/1000] loss0.030-|Sample:0.02|
# EPOCH[267/1000] loss0.029-|Sample:0.01|
# EPOCH[268/1000] loss0.030-|Sample:0.02|
# EPOCH[269/1000] loss0.029-|Sample:0.01|
# EPOCH[270/1000] loss0.030-|Sample:0.02|
# [TEST]
# {'precision': array([0.0052374]), 'recall': array([0.04513045]), 'ndcg': array([0.02517234])}
# EPOCH[271/1000] loss0.029-|Sample:0.02|
# EPOCH[272/1000] loss0.028-|Sample:0.02|
# EPOCH[273/1000] loss0.028-|Sample:0.01|
# EPOCH[274/1000] loss0.028-|Sample:0.02|
# EPOCH[275/1000] loss0.028-|Sample:0.01|
# EPOCH[276/1000] loss0.028-|Sample:0.01|
# EPOCH[277/1000] loss0.028-|Sample:0.01|
# EPOCH[278/1000] loss0.028-|Sample:0.02|
# EPOCH[279/1000] loss0.028-|Sample:0.01|
# EPOCH[280/1000] loss0.027-|Sample:0.01|
# [TEST]
# {'precision': array([0.00524351]), 'recall': array([0.04503639]), 'ndcg': array([0.02510568])}
# EPOCH[281/1000] loss0.027-|Sample:0.02|
# EPOCH[282/1000] loss0.027-|Sample:0.01|
# EPOCH[283/1000] loss0.026-|Sample:0.01|
# EPOCH[284/1000] loss0.026-|Sample:0.02|
# EPOCH[285/1000] loss0.027-|Sample:0.01|
# EPOCH[286/1000] loss0.027-|Sample:0.02|
# EPOCH[287/1000] loss0.027-|Sample:0.01|
# EPOCH[288/1000] loss0.026-|Sample:0.01|
# EPOCH[289/1000] loss0.027-|Sample:0.01|
# EPOCH[290/1000] loss0.027-|Sample:0.02|
# [TEST]
# {'precision': array([0.0052068]), 'recall': array([0.04461946]), 'ndcg': array([0.02496131])}
# EPOCH[291/1000] loss0.026-|Sample:0.02|
# EPOCH[292/1000] loss0.027-|Sample:0.01|
# EPOCH[293/1000] loss0.026-|Sample:0.01|
# EPOCH[294/1000] loss0.026-|Sample:0.01|
# EPOCH[295/1000] loss0.024-|Sample:0.01|
# EPOCH[296/1000] loss0.024-|Sample:0.02|
# EPOCH[297/1000] loss0.026-|Sample:0.01|
# EPOCH[298/1000] loss0.025-|Sample:0.02|
# EPOCH[299/1000] loss0.026-|Sample:0.01|
# EPOCH[300/1000] loss0.024-|Sample:0.01|
# [TEST]
# {'precision': array([0.00518845]), 'recall': array([0.04427581]), 'ndcg': array([0.02482059])}
# EPOCH[301/1000] loss0.024-|Sample:0.02|
# EPOCH[302/1000] loss0.026-|Sample:0.01|
# EPOCH[303/1000] loss0.025-|Sample:0.02|
# EPOCH[304/1000] loss0.024-|Sample:0.01|
# EPOCH[305/1000] loss0.025-|Sample:0.01|
# EPOCH[306/1000] loss0.025-|Sample:0.02|
# EPOCH[307/1000] loss0.024-|Sample:0.01|
# EPOCH[308/1000] loss0.024-|Sample:0.01|
# EPOCH[309/1000] loss0.024-|Sample:0.01|
# EPOCH[310/1000] loss0.024-|Sample:0.02|
# [TEST]
# {'precision': array([0.00512115]), 'recall': array([0.04327398]), 'ndcg': array([0.02459574])}
# EPOCH[311/1000] loss0.024-|Sample:0.02|
# EPOCH[312/1000] loss0.022-|Sample:0.02|
# EPOCH[313/1000] loss0.023-|Sample:0.01|
# EPOCH[314/1000] loss0.024-|Sample:0.01|
# EPOCH[315/1000] loss0.023-|Sample:0.01|
# EPOCH[316/1000] loss0.023-|Sample:0.01|
# EPOCH[317/1000] loss0.024-|Sample:0.01|
# EPOCH[318/1000] loss0.024-|Sample:0.02|
# EPOCH[319/1000] loss0.023-|Sample:0.01|
# EPOCH[320/1000] loss0.023-|Sample:0.02|
# [TEST]
# {'precision': array([0.00517009]), 'recall': array([0.04371883]), 'ndcg': array([0.02471263])}
# EPOCH[321/1000] loss0.023-|Sample:0.02|
# EPOCH[322/1000] loss0.023-|Sample:0.01|
# EPOCH[323/1000] loss0.023-|Sample:0.01|
# EPOCH[324/1000] loss0.022-|Sample:0.02|
# EPOCH[325/1000] loss0.023-|Sample:0.01|
# EPOCH[326/1000] loss0.022-|Sample:0.02|
# EPOCH[327/1000] loss0.022-|Sample:0.01|
# EPOCH[328/1000] loss0.023-|Sample:0.02|
# EPOCH[329/1000] loss0.022-|Sample:0.02|
# EPOCH[330/1000] loss0.023-|Sample:0.01|
# [TEST]
# {'precision': array([0.00510891]), 'recall': array([0.04353323]), 'ndcg': array([0.02441613])}
# EPOCH[331/1000] loss0.022-|Sample:0.02|
# EPOCH[332/1000] loss0.022-|Sample:0.02|
# EPOCH[333/1000] loss0.022-|Sample:0.01|
# EPOCH[334/1000] loss0.021-|Sample:0.01|
# EPOCH[335/1000] loss0.021-|Sample:0.01|
# EPOCH[336/1000] loss0.021-|Sample:0.02|
# EPOCH[337/1000] loss0.021-|Sample:0.01|
# EPOCH[338/1000] loss0.020-|Sample:0.02|
# EPOCH[339/1000] loss0.021-|Sample:0.01|
# EPOCH[340/1000] loss0.021-|Sample:0.01|
# [TEST]
# {'precision': array([0.00507832]), 'recall': array([0.0435091]), 'ndcg': array([0.02432932])}
# EPOCH[341/1000] loss0.020-|Sample:0.02|
# EPOCH[342/1000] loss0.021-|Sample:0.01|
# EPOCH[343/1000] loss0.021-|Sample:0.01|
# EPOCH[344/1000] loss0.021-|Sample:0.02|
# EPOCH[345/1000] loss0.021-|Sample:0.01|
# EPOCH[346/1000] loss0.021-|Sample:0.02|
# EPOCH[347/1000] loss0.020-|Sample:0.01|
# EPOCH[348/1000] loss0.021-|Sample:0.01|
# EPOCH[349/1000] loss0.020-|Sample:0.01|
# EPOCH[350/1000] loss0.021-|Sample:0.02|
# [TEST]
# {'precision': array([0.00506608]), 'recall': array([0.04307591]), 'ndcg': array([0.02399525])}
# EPOCH[351/1000] loss0.019-|Sample:0.02|
# EPOCH[352/1000] loss0.019-|Sample:0.02|
# EPOCH[353/1000] loss0.020-|Sample:0.01|
# EPOCH[354/1000] loss0.020-|Sample:0.01|
# EPOCH[355/1000] loss0.019-|Sample:0.01|
# EPOCH[356/1000] loss0.020-|Sample:0.02|
# EPOCH[357/1000] loss0.020-|Sample:0.02|
# EPOCH[358/1000] loss0.020-|Sample:0.01|
# EPOCH[359/1000] loss0.019-|Sample:0.01|
# EPOCH[360/1000] loss0.019-|Sample:0.02|
# [TEST]
# {'precision': array([0.00491924]), 'recall': array([0.04145359]), 'ndcg': array([0.02352476])}
# EPOCH[361/1000] loss0.019-|Sample:0.02|
# EPOCH[362/1000] loss0.020-|Sample:0.02|
# EPOCH[363/1000] loss0.019-|Sample:0.01|
# EPOCH[364/1000] loss0.021-|Sample:0.02|
# EPOCH[365/1000] loss0.019-|Sample:0.01|
# EPOCH[366/1000] loss0.020-|Sample:0.02|
# EPOCH[367/1000] loss0.019-|Sample:0.02|
# EPOCH[368/1000] loss0.019-|Sample:0.01|
# EPOCH[369/1000] loss0.018-|Sample:0.02|
# EPOCH[370/1000] loss0.019-|Sample:0.01|
# [TEST]
# {'precision': array([0.00482134]), 'recall': array([0.04097573]), 'ndcg': array([0.02317513])}
# EPOCH[371/1000] loss0.018-|Sample:0.02|
# EPOCH[372/1000] loss0.019-|Sample:0.02|
# EPOCH[373/1000] loss0.019-|Sample:0.01|
# EPOCH[374/1000] loss0.018-|Sample:0.01|
# EPOCH[375/1000] loss0.019-|Sample:0.01|
# EPOCH[376/1000] loss0.019-|Sample:0.01|
# EPOCH[377/1000] loss0.019-|Sample:0.01|
# EPOCH[378/1000] loss0.018-|Sample:0.01|
# EPOCH[379/1000] loss0.019-|Sample:0.01|
# EPOCH[380/1000] loss0.019-|Sample:0.02|
# [TEST]
# {'precision': array([0.00478463]), 'recall': array([0.04056466]), 'ndcg': array([0.02274315])}
# EPOCH[381/1000] loss0.018-|Sample:0.02|
# EPOCH[382/1000] loss0.019-|Sample:0.01|
# EPOCH[383/1000] loss0.018-|Sample:0.01|
# EPOCH[384/1000] loss0.018-|Sample:0.02|
# EPOCH[385/1000] loss0.018-|Sample:0.01|
# EPOCH[386/1000] loss0.018-|Sample:0.02|
# EPOCH[387/1000] loss0.018-|Sample:0.01|
# EPOCH[388/1000] loss0.018-|Sample:0.02|
# EPOCH[389/1000] loss0.018-|Sample:0.01|
# EPOCH[390/1000] loss0.018-|Sample:0.01|
# [TEST]
# {'precision': array([0.00475404]), 'recall': array([0.04027107]), 'ndcg': array([0.02270049])}
# EPOCH[391/1000] loss0.018-|Sample:0.02|
# EPOCH[392/1000] loss0.017-|Sample:0.02|
# EPOCH[393/1000] loss0.017-|Sample:0.01|
# EPOCH[394/1000] loss0.017-|Sample:0.02|
# EPOCH[395/1000] loss0.018-|Sample:0.01|
# EPOCH[396/1000] loss0.018-|Sample:0.01|
# EPOCH[397/1000] loss0.017-|Sample:0.01|
# EPOCH[398/1000] loss0.018-|Sample:0.01|
# EPOCH[399/1000] loss0.017-|Sample:0.01|
# EPOCH[400/1000] loss0.018-|Sample:0.01|
# [TEST]
# {'precision': array([0.00471121]), 'recall': array([0.04023052]), 'ndcg': array([0.02259609])}
# EPOCH[401/1000] loss0.018-|Sample:0.02|
# EPOCH[402/1000] loss0.018-|Sample:0.01|
# EPOCH[403/1000] loss0.017-|Sample:0.01|
# EPOCH[404/1000] loss0.016-|Sample:0.01|
# EPOCH[405/1000] loss0.017-|Sample:0.01|
# EPOCH[406/1000] loss0.017-|Sample:0.01|
# EPOCH[407/1000] loss0.016-|Sample:0.01|
# EPOCH[408/1000] loss0.017-|Sample:0.02|
# EPOCH[409/1000] loss0.017-|Sample:0.01|
# EPOCH[410/1000] loss0.017-|Sample:0.02|
# [TEST]
# {'precision': array([0.00470509]), 'recall': array([0.0399959]), 'ndcg': array([0.02241038])}
# EPOCH[411/1000] loss0.016-|Sample:0.02|
# EPOCH[412/1000] loss0.017-|Sample:0.01|
# EPOCH[413/1000] loss0.016-|Sample:0.01|
# EPOCH[414/1000] loss0.017-|Sample:0.02|
# EPOCH[415/1000] loss0.017-|Sample:0.01|
# EPOCH[416/1000] loss0.017-|Sample:0.02|
# EPOCH[417/1000] loss0.017-|Sample:0.01|
# EPOCH[418/1000] loss0.016-|Sample:0.01|
# EPOCH[419/1000] loss0.016-|Sample:0.01|
# EPOCH[420/1000] loss0.016-|Sample:0.01|
# [TEST]
# {'precision': array([0.00468674]), 'recall': array([0.03980477]), 'ndcg': array([0.02219286])}
# EPOCH[421/1000] loss0.017-|Sample:0.02|
# EPOCH[422/1000] loss0.016-|Sample:0.02|
# EPOCH[423/1000] loss0.016-|Sample:0.01|
# EPOCH[424/1000] loss0.015-|Sample:0.02|
# EPOCH[425/1000] loss0.016-|Sample:0.01|
# EPOCH[426/1000] loss0.016-|Sample:0.01|
# EPOCH[427/1000] loss0.017-|Sample:0.01|
# EPOCH[428/1000] loss0.016-|Sample:0.01|
# EPOCH[429/1000] loss0.016-|Sample:0.01|
# EPOCH[430/1000] loss0.015-|Sample:0.02|
# [TEST]
# {'precision': array([0.00469285]), 'recall': array([0.04001038]), 'ndcg': array([0.02229228])}
# EPOCH[431/1000] loss0.017-|Sample:0.02|
# EPOCH[432/1000] loss0.015-|Sample:0.01|
# EPOCH[433/1000] loss0.015-|Sample:0.02|
# EPOCH[434/1000] loss0.015-|Sample:0.01|
# EPOCH[435/1000] loss0.016-|Sample:0.01|
# EPOCH[436/1000] loss0.015-|Sample:0.01|
# EPOCH[437/1000] loss0.015-|Sample:0.01|
# EPOCH[438/1000] loss0.015-|Sample:0.01|
# EPOCH[439/1000] loss0.016-|Sample:0.01|
# EPOCH[440/1000] loss0.015-|Sample:0.01|
# [TEST]
# {'precision': array([0.00468062]), 'recall': array([0.03994952]), 'ndcg': array([0.02226198])}
# EPOCH[441/1000] loss0.015-|Sample:0.02|
# EPOCH[442/1000] loss0.015-|Sample:0.01|
# EPOCH[443/1000] loss0.015-|Sample:0.01|
# EPOCH[444/1000] loss0.015-|Sample:0.02|
# EPOCH[445/1000] loss0.016-|Sample:0.01|
# EPOCH[446/1000] loss0.015-|Sample:0.02|
# EPOCH[447/1000] loss0.016-|Sample:0.01|
# EPOCH[448/1000] loss0.015-|Sample:0.01|
# EPOCH[449/1000] loss0.014-|Sample:0.01|
# EPOCH[450/1000] loss0.015-|Sample:0.01|
# [TEST]
# {'precision': array([0.00465614]), 'recall': array([0.04012148]), 'ndcg': array([0.02242162])}
# EPOCH[451/1000] loss0.016-|Sample:0.02|
# EPOCH[452/1000] loss0.015-|Sample:0.01|
# EPOCH[453/1000] loss0.015-|Sample:0.01|
# EPOCH[454/1000] loss0.015-|Sample:0.02|
# EPOCH[455/1000] loss0.016-|Sample:0.02|
# EPOCH[456/1000] loss0.015-|Sample:0.01|
# EPOCH[457/1000] loss0.014-|Sample:0.02|
# EPOCH[458/1000] loss0.014-|Sample:0.01|
# EPOCH[459/1000] loss0.015-|Sample:0.02|
# EPOCH[460/1000] loss0.015-|Sample:0.01|
# [TEST]
# {'precision': array([0.00462555]), 'recall': array([0.0400164]), 'ndcg': array([0.02238574])}
# EPOCH[461/1000] loss0.015-|Sample:0.02|
# EPOCH[462/1000] loss0.015-|Sample:0.02|
# EPOCH[463/1000] loss0.015-|Sample:0.01|
# EPOCH[464/1000] loss0.014-|Sample:0.02|
# EPOCH[465/1000] loss0.015-|Sample:0.01|
# EPOCH[466/1000] loss0.014-|Sample:0.02|
# EPOCH[467/1000] loss0.014-|Sample:0.01|
# EPOCH[468/1000] loss0.015-|Sample:0.02|
# EPOCH[469/1000] loss0.014-|Sample:0.01|
# EPOCH[470/1000] loss0.014-|Sample:0.02|
# [TEST]
# {'precision': array([0.00461943]), 'recall': array([0.04000292]), 'ndcg': array([0.02223084])}
# EPOCH[471/1000] loss0.015-|Sample:0.02|
# EPOCH[472/1000] loss0.014-|Sample:0.01|
# EPOCH[473/1000] loss0.015-|Sample:0.01|
# EPOCH[474/1000] loss0.013-|Sample:0.02|
# EPOCH[475/1000] loss0.014-|Sample:0.01|
# EPOCH[476/1000] loss0.014-|Sample:0.02|
# EPOCH[477/1000] loss0.014-|Sample:0.01|
# EPOCH[478/1000] loss0.015-|Sample:0.02|
# EPOCH[479/1000] loss0.014-|Sample:0.01|
# EPOCH[480/1000] loss0.014-|Sample:0.01|
# [TEST]
# {'precision': array([0.00463167]), 'recall': array([0.04009885]), 'ndcg': array([0.02228372])}
# EPOCH[481/1000] loss0.014-|Sample:0.02|
# EPOCH[482/1000] loss0.013-|Sample:0.01|
# EPOCH[483/1000] loss0.014-|Sample:0.01|
# EPOCH[484/1000] loss0.014-|Sample:0.02|
# EPOCH[485/1000] loss0.014-|Sample:0.02|
# EPOCH[486/1000] loss0.013-|Sample:0.02|
# EPOCH[487/1000] loss0.014-|Sample:0.01|
# EPOCH[488/1000] loss0.014-|Sample:0.01|
# EPOCH[489/1000] loss0.014-|Sample:0.01|
# EPOCH[490/1000] loss0.014-|Sample:0.01|
# [TEST]
# {'precision': array([0.00458884]), 'recall': array([0.03992258]), 'ndcg': array([0.02210527])}
# EPOCH[491/1000] loss0.014-|Sample:0.02|
# EPOCH[492/1000] loss0.014-|Sample:0.01|
# EPOCH[493/1000] loss0.014-|Sample:0.01|
# EPOCH[494/1000] loss0.013-|Sample:0.02|
# EPOCH[495/1000] loss0.014-|Sample:0.01|
# EPOCH[496/1000] loss0.014-|Sample:0.01|
# EPOCH[497/1000] loss0.014-|Sample:0.02|
# EPOCH[498/1000] loss0.014-|Sample:0.01|
# EPOCH[499/1000] loss0.014-|Sample:0.01|
# EPOCH[500/1000] loss0.014-|Sample:0.01|
# [TEST]
# {'precision': array([0.00452766]), 'recall': array([0.03938838]), 'ndcg': array([0.02186891])}
# EPOCH[501/1000] loss0.014-|Sample:0.02|
# EPOCH[502/1000] loss0.014-|Sample:0.01|
# EPOCH[503/1000] loss0.013-|Sample:0.01|
# EPOCH[504/1000] loss0.013-|Sample:0.01|
# EPOCH[505/1000] loss0.014-|Sample:0.01|
# EPOCH[506/1000] loss0.013-|Sample:0.01|
# EPOCH[507/1000] loss0.013-|Sample:0.01|
# EPOCH[508/1000] loss0.013-|Sample:0.01|
# EPOCH[509/1000] loss0.013-|Sample:0.01|
# EPOCH[510/1000] loss0.014-|Sample:0.01|
# [TEST]
# {'precision': array([0.00449706]), 'recall': array([0.03887802]), 'ndcg': array([0.02168302])}
# EPOCH[511/1000] loss0.013-|Sample:0.02|
# EPOCH[512/1000] loss0.014-|Sample:0.02|
# EPOCH[513/1000] loss0.013-|Sample:0.01|
# EPOCH[514/1000] loss0.014-|Sample:0.01|
# EPOCH[515/1000] loss0.013-|Sample:0.01|
# EPOCH[516/1000] loss0.013-|Sample:0.01|
# EPOCH[517/1000] loss0.013-|Sample:0.02|
# EPOCH[518/1000] loss0.013-|Sample:0.01|
# EPOCH[519/1000] loss0.013-|Sample:0.01|
# EPOCH[520/1000] loss0.013-|Sample:0.02|
# [TEST]
# {'precision': array([0.00439917]), 'recall': array([0.03828978]), 'ndcg': array([0.02127878])}
# EPOCH[521/1000] loss0.013-|Sample:0.02|
# EPOCH[522/1000] loss0.014-|Sample:0.02|
# EPOCH[523/1000] loss0.014-|Sample:0.01|
# EPOCH[524/1000] loss0.014-|Sample:0.02|
# EPOCH[525/1000] loss0.013-|Sample:0.01|
# EPOCH[526/1000] loss0.013-|Sample:0.02|
# EPOCH[527/1000] loss0.013-|Sample:0.01|
# EPOCH[528/1000] loss0.013-|Sample:0.02|
# EPOCH[529/1000] loss0.013-|Sample:0.01|
# EPOCH[530/1000] loss0.013-|Sample:0.02|
# [TEST]
# {'precision': array([0.0044114]), 'recall': array([0.03867177]), 'ndcg': array([0.02141884])}
# EPOCH[531/1000] loss0.013-|Sample:0.02|
# EPOCH[532/1000] loss0.013-|Sample:0.01|
# EPOCH[533/1000] loss0.013-|Sample:0.02|
# EPOCH[534/1000] loss0.013-|Sample:0.01|
# EPOCH[535/1000] loss0.013-|Sample:0.01|
# EPOCH[536/1000] loss0.013-|Sample:0.01|
# EPOCH[537/1000] loss0.013-|Sample:0.02|
# EPOCH[538/1000] loss0.013-|Sample:0.01|
# EPOCH[539/1000] loss0.013-|Sample:0.02|
# EPOCH[540/1000] loss0.013-|Sample:0.01|
# [TEST]
# {'precision': array([0.0044114]), 'recall': array([0.038649]), 'ndcg': array([0.02134017])}
# EPOCH[541/1000] loss0.013-|Sample:0.02|
# EPOCH[542/1000] loss0.012-|Sample:0.02|
# EPOCH[543/1000] loss0.013-|Sample:0.01|
# EPOCH[544/1000] loss0.013-|Sample:0.02|
# EPOCH[545/1000] loss0.012-|Sample:0.01|
# EPOCH[546/1000] loss0.012-|Sample:0.01|
# EPOCH[547/1000] loss0.012-|Sample:0.01|
# EPOCH[548/1000] loss0.013-|Sample:0.01|
# EPOCH[549/1000] loss0.013-|Sample:0.01|
# EPOCH[550/1000] loss0.013-|Sample:0.02|
# [TEST]
# {'precision': array([0.00442976]), 'recall': array([0.03892929]), 'ndcg': array([0.02123738])}
# EPOCH[551/1000] loss0.013-|Sample:0.02|
# EPOCH[552/1000] loss0.012-|Sample:0.01|
# EPOCH[553/1000] loss0.013-|Sample:0.01|
# EPOCH[554/1000] loss0.012-|Sample:0.02|
# EPOCH[555/1000] loss0.012-|Sample:0.01|
# EPOCH[556/1000] loss0.013-|Sample:0.01|
# EPOCH[557/1000] loss0.012-|Sample:0.01|
# EPOCH[558/1000] loss0.013-|Sample:0.02|
# EPOCH[559/1000] loss0.013-|Sample:0.01|
# EPOCH[560/1000] loss0.012-|Sample:0.01|
# [TEST]
# {'precision': array([0.00439305]), 'recall': array([0.03867231]), 'ndcg': array([0.02115797])}
# EPOCH[561/1000] loss0.012-|Sample:0.02|
# EPOCH[562/1000] loss0.012-|Sample:0.02|
# EPOCH[563/1000] loss0.013-|Sample:0.02|
# EPOCH[564/1000] loss0.012-|Sample:0.01|
# EPOCH[565/1000] loss0.012-|Sample:0.01|
# EPOCH[566/1000] loss0.012-|Sample:0.01|
# EPOCH[567/1000] loss0.012-|Sample:0.02|
# EPOCH[568/1000] loss0.012-|Sample:0.01|
# EPOCH[569/1000] loss0.012-|Sample:0.01|
# EPOCH[570/1000] loss0.012-|Sample:0.02|
# [TEST]
# {'precision': array([0.00440529]), 'recall': array([0.03862064]), 'ndcg': array([0.02119921])}
# EPOCH[571/1000] loss0.012-|Sample:0.02|
# EPOCH[572/1000] loss0.013-|Sample:0.02|
# EPOCH[573/1000] loss0.013-|Sample:0.01|
# EPOCH[574/1000] loss0.011-|Sample:0.01|
# EPOCH[575/1000] loss0.013-|Sample:0.01|
# EPOCH[576/1000] loss0.012-|Sample:0.01|
# EPOCH[577/1000] loss0.012-|Sample:0.01|
# EPOCH[578/1000] loss0.012-|Sample:0.02|
# EPOCH[579/1000] loss0.013-|Sample:0.01|
# EPOCH[580/1000] loss0.012-|Sample:0.01|
# [TEST]
# {'precision': array([0.00439305]), 'recall': array([0.03833424]), 'ndcg': array([0.02121361])}
# EPOCH[581/1000] loss0.012-|Sample:0.01|
# EPOCH[582/1000] loss0.012-|Sample:0.01|
# EPOCH[583/1000] loss0.012-|Sample:0.01|
# EPOCH[584/1000] loss0.012-|Sample:0.02|
# EPOCH[585/1000] loss0.012-|Sample:0.01|
# EPOCH[586/1000] loss0.012-|Sample:0.01|
# EPOCH[587/1000] loss0.012-|Sample:0.01|
# EPOCH[588/1000] loss0.012-|Sample:0.02|
# EPOCH[589/1000] loss0.012-|Sample:0.01|
# EPOCH[590/1000] loss0.012-|Sample:0.02|
# [TEST]
# {'precision': array([0.00438693]), 'recall': array([0.0384806]), 'ndcg': array([0.02119847])}
# EPOCH[591/1000] loss0.012-|Sample:0.01|
# EPOCH[592/1000] loss0.012-|Sample:0.02|
# EPOCH[593/1000] loss0.012-|Sample:0.01|
# EPOCH[594/1000] loss0.012-|Sample:0.01|
# EPOCH[595/1000] loss0.012-|Sample:0.01|
# EPOCH[596/1000] loss0.012-|Sample:0.02|
# EPOCH[597/1000] loss0.011-|Sample:0.01|
# EPOCH[598/1000] loss0.011-|Sample:0.01|
# EPOCH[599/1000] loss0.011-|Sample:0.01|
# EPOCH[600/1000] loss0.011-|Sample:0.02|
# [TEST]
# {'precision': array([0.00431963]), 'recall': array([0.03775148]), 'ndcg': array([0.02108566])}
# EPOCH[601/1000] loss0.012-|Sample:0.02|
# EPOCH[602/1000] loss0.012-|Sample:0.02|
# EPOCH[603/1000] loss0.011-|Sample:0.02|
# EPOCH[604/1000] loss0.012-|Sample:0.01|
# EPOCH[605/1000] loss0.012-|Sample:0.01|
# EPOCH[606/1000] loss0.012-|Sample:0.01|
# EPOCH[607/1000] loss0.012-|Sample:0.02|
# EPOCH[608/1000] loss0.012-|Sample:0.02|
# EPOCH[609/1000] loss0.011-|Sample:0.01|
# EPOCH[610/1000] loss0.011-|Sample:0.02|
# [TEST]
# {'precision': array([0.00436858]), 'recall': array([0.03828991]), 'ndcg': array([0.02108589])}
# EPOCH[611/1000] loss0.012-|Sample:0.02|
# EPOCH[612/1000] loss0.012-|Sample:0.01|
# EPOCH[613/1000] loss0.012-|Sample:0.01|
# EPOCH[614/1000] loss0.012-|Sample:0.02|
# EPOCH[615/1000] loss0.012-|Sample:0.01|
# EPOCH[616/1000] loss0.011-|Sample:0.02|
# EPOCH[617/1000] loss0.012-|Sample:0.01|
# EPOCH[618/1000] loss0.012-|Sample:0.02|
# EPOCH[619/1000] loss0.012-|Sample:0.01|
# EPOCH[620/1000] loss0.011-|Sample:0.02|
# [TEST]
# {'precision': array([0.00430127]), 'recall': array([0.03776338]), 'ndcg': array([0.02084935])}
# EPOCH[621/1000] loss0.011-|Sample:0.02|
# EPOCH[622/1000] loss0.012-|Sample:0.02|
# EPOCH[623/1000] loss0.011-|Sample:0.01|
# EPOCH[624/1000] loss0.012-|Sample:0.01|
# EPOCH[625/1000] loss0.011-|Sample:0.02|
# EPOCH[626/1000] loss0.011-|Sample:0.01|
# EPOCH[627/1000] loss0.011-|Sample:0.02|
# EPOCH[628/1000] loss0.012-|Sample:0.01|
# EPOCH[629/1000] loss0.012-|Sample:0.02|
# EPOCH[630/1000] loss0.011-|Sample:0.01|
# [TEST]
# {'precision': array([0.00430739]), 'recall': array([0.03783272]), 'ndcg': array([0.02073895])}
# EPOCH[631/1000] loss0.011-|Sample:0.02|
# EPOCH[632/1000] loss0.012-|Sample:0.01|
# EPOCH[633/1000] loss0.011-|Sample:0.01|
# EPOCH[634/1000] loss0.011-|Sample:0.01|
# EPOCH[635/1000] loss0.011-|Sample:0.01|
# EPOCH[636/1000] loss0.011-|Sample:0.01|
# EPOCH[637/1000] loss0.011-|Sample:0.01|
# EPOCH[638/1000] loss0.011-|Sample:0.02|
# EPOCH[639/1000] loss0.012-|Sample:0.01|
# EPOCH[640/1000] loss0.011-|Sample:0.02|
# [TEST]
# {'precision': array([0.00430127]), 'recall': array([0.03770424]), 'ndcg': array([0.02076765])}
# EPOCH[641/1000] loss0.011-|Sample:0.02|
# EPOCH[642/1000] loss0.011-|Sample:0.02|
# EPOCH[643/1000] loss0.011-|Sample:0.01|
# EPOCH[644/1000] loss0.011-|Sample:0.01|
# EPOCH[645/1000] loss0.011-|Sample:0.01|
# EPOCH[646/1000] loss0.011-|Sample:0.01|
# EPOCH[647/1000] loss0.011-|Sample:0.01|
# EPOCH[648/1000] loss0.012-|Sample:0.02|
# EPOCH[649/1000] loss0.011-|Sample:0.01|
# EPOCH[650/1000] loss0.011-|Sample:0.02|
# [TEST]
# {'precision': array([0.00432575]), 'recall': array([0.03791036]), 'ndcg': array([0.02077083])}
# EPOCH[651/1000] loss0.011-|Sample:0.02|
# EPOCH[652/1000] loss0.011-|Sample:0.01|
# EPOCH[653/1000] loss0.011-|Sample:0.01|
# EPOCH[654/1000] loss0.011-|Sample:0.02|
# EPOCH[655/1000] loss0.011-|Sample:0.02|
# EPOCH[656/1000] loss0.011-|Sample:0.01|
# EPOCH[657/1000] loss0.011-|Sample:0.01|
# EPOCH[658/1000] loss0.011-|Sample:0.01|
# EPOCH[659/1000] loss0.011-|Sample:0.01|
# EPOCH[660/1000] loss0.011-|Sample:0.01|
# [TEST]
# {'precision': array([0.00429515]), 'recall': array([0.0377338]), 'ndcg': array([0.02076357])}
# EPOCH[661/1000] loss0.011-|Sample:0.02|
# EPOCH[662/1000] loss0.011-|Sample:0.01|
# EPOCH[663/1000] loss0.011-|Sample:0.01|
# EPOCH[664/1000] loss0.011-|Sample:0.02|
# EPOCH[665/1000] loss0.011-|Sample:0.01|
# EPOCH[666/1000] loss0.011-|Sample:0.02|
# EPOCH[667/1000] loss0.011-|Sample:0.01|
# EPOCH[668/1000] loss0.011-|Sample:0.02|
# EPOCH[669/1000] loss0.011-|Sample:0.01|
# EPOCH[670/1000] loss0.011-|Sample:0.01|
# [TEST]
# {'precision': array([0.00429515]), 'recall': array([0.03782033]), 'ndcg': array([0.02071618])}
# EPOCH[671/1000] loss0.011-|Sample:0.02|
# EPOCH[672/1000] loss0.011-|Sample:0.01|
# EPOCH[673/1000] loss0.011-|Sample:0.01|
# EPOCH[674/1000] loss0.011-|Sample:0.01|
# EPOCH[675/1000] loss0.011-|Sample:0.01|
# EPOCH[676/1000] loss0.011-|Sample:0.01|
# EPOCH[677/1000] loss0.011-|Sample:0.01|
# EPOCH[678/1000] loss0.011-|Sample:0.02|
# EPOCH[679/1000] loss0.011-|Sample:0.01|
# EPOCH[680/1000] loss0.011-|Sample:0.01|
# [TEST]
# {'precision': array([0.0042768]), 'recall': array([0.03783874]), 'ndcg': array([0.02071518])}
# EPOCH[681/1000] loss0.011-|Sample:0.02|
# EPOCH[682/1000] loss0.011-|Sample:0.02|
# EPOCH[683/1000] loss0.011-|Sample:0.01|
# EPOCH[684/1000] loss0.011-|Sample:0.02|
# EPOCH[685/1000] loss0.011-|Sample:0.02|
# EPOCH[686/1000] loss0.011-|Sample:0.01|
# EPOCH[687/1000] loss0.011-|Sample:0.02|
# EPOCH[688/1000] loss0.011-|Sample:0.01|
# EPOCH[689/1000] loss0.011-|Sample:0.01|
# EPOCH[690/1000] loss0.011-|Sample:0.01|
# [TEST]
# {'precision': array([0.00422785]), 'recall': array([0.03747688]), 'ndcg': array([0.02065916])}
# EPOCH[691/1000] loss0.011-|Sample:0.02|
# EPOCH[692/1000] loss0.011-|Sample:0.02|
# EPOCH[693/1000] loss0.011-|Sample:0.01|
# EPOCH[694/1000] loss0.011-|Sample:0.02|
# EPOCH[695/1000] loss0.011-|Sample:0.01|
# EPOCH[696/1000] loss0.011-|Sample:0.01|
# EPOCH[697/1000] loss0.011-|Sample:0.01|
# EPOCH[698/1000] loss0.011-|Sample:0.01|
# EPOCH[699/1000] loss0.011-|Sample:0.01|
# EPOCH[700/1000] loss0.011-|Sample:0.02|
# [TEST]
# {'precision': array([0.00423397]), 'recall': array([0.03743521]), 'ndcg': array([0.02057571])}
# EPOCH[701/1000] loss0.010-|Sample:0.02|
# EPOCH[702/1000] loss0.011-|Sample:0.01|
# EPOCH[703/1000] loss0.010-|Sample:0.01|
# EPOCH[704/1000] loss0.010-|Sample:0.02|
# EPOCH[705/1000] loss0.010-|Sample:0.01|
# EPOCH[706/1000] loss0.010-|Sample:0.01|
# EPOCH[707/1000] loss0.011-|Sample:0.01|
# EPOCH[708/1000] loss0.011-|Sample:0.01|
# EPOCH[709/1000] loss0.011-|Sample:0.01|
# EPOCH[710/1000] loss0.011-|Sample:0.01|
# [TEST]
# {'precision': array([0.0042768]), 'recall': array([0.03758109]), 'ndcg': array([0.02068485])}
# EPOCH[711/1000] loss0.011-|Sample:0.02|
# EPOCH[712/1000] loss0.010-|Sample:0.01|
# EPOCH[713/1000] loss0.010-|Sample:0.01|
# EPOCH[714/1000] loss0.010-|Sample:0.01|
# EPOCH[715/1000] loss0.011-|Sample:0.01|
# EPOCH[716/1000] loss0.010-|Sample:0.02|
# EPOCH[717/1000] loss0.011-|Sample:0.01|
# EPOCH[718/1000] loss0.011-|Sample:0.01|
# EPOCH[719/1000] loss0.011-|Sample:0.02|
# EPOCH[720/1000] loss0.011-|Sample:0.01|
# [TEST]
# {'precision': array([0.00419726]), 'recall': array([0.03690281]), 'ndcg': array([0.02040637])}
# EPOCH[721/1000] loss0.011-|Sample:0.02|
# EPOCH[722/1000] loss0.011-|Sample:0.02|
# EPOCH[723/1000] loss0.011-|Sample:0.01|
# EPOCH[724/1000] loss0.010-|Sample:0.01|
# EPOCH[725/1000] loss0.010-|Sample:0.01|
# EPOCH[726/1000] loss0.010-|Sample:0.02|
# EPOCH[727/1000] loss0.010-|Sample:0.01|
# EPOCH[728/1000] loss0.011-|Sample:0.02|
# EPOCH[729/1000] loss0.011-|Sample:0.01|
# EPOCH[730/1000] loss0.010-|Sample:0.02|
# [TEST]
# {'precision': array([0.00421561]), 'recall': array([0.0372373]), 'ndcg': array([0.02056286])}
# EPOCH[731/1000] loss0.011-|Sample:0.02|
# EPOCH[732/1000] loss0.010-|Sample:0.02|
# EPOCH[733/1000] loss0.011-|Sample:0.01|
# EPOCH[734/1000] loss0.010-|Sample:0.02|
# EPOCH[735/1000] loss0.010-|Sample:0.02|
# EPOCH[736/1000] loss0.011-|Sample:0.02|
# EPOCH[737/1000] loss0.010-|Sample:0.01|
# EPOCH[738/1000] loss0.010-|Sample:0.01|
# EPOCH[739/1000] loss0.010-|Sample:0.01|
# EPOCH[740/1000] loss0.010-|Sample:0.01|
# [TEST]
# {'precision': array([0.00422173]), 'recall': array([0.03712216]), 'ndcg': array([0.02035281])}
# EPOCH[741/1000] loss0.011-|Sample:0.02|
# EPOCH[742/1000] loss0.011-|Sample:0.02|
# EPOCH[743/1000] loss0.010-|Sample:0.02|
# EPOCH[744/1000] loss0.010-|Sample:0.02|
# EPOCH[745/1000] loss0.010-|Sample:0.01|
# EPOCH[746/1000] loss0.011-|Sample:0.02|
# EPOCH[747/1000] loss0.010-|Sample:0.02|
# EPOCH[748/1000] loss0.011-|Sample:0.01|
# EPOCH[749/1000] loss0.010-|Sample:0.01|
# EPOCH[750/1000] loss0.010-|Sample:0.01|
# [TEST]
# {'precision': array([0.0042095]), 'recall': array([0.03720286]), 'ndcg': array([0.02036209])}
# EPOCH[751/1000] loss0.010-|Sample:0.02|
# EPOCH[752/1000] loss0.010-|Sample:0.01|
# EPOCH[753/1000] loss0.010-|Sample:0.02|
# EPOCH[754/1000] loss0.010-|Sample:0.01|
# EPOCH[755/1000] loss0.010-|Sample:0.01|
# EPOCH[756/1000] loss0.010-|Sample:0.01|
# EPOCH[757/1000] loss0.010-|Sample:0.02|
# EPOCH[758/1000] loss0.010-|Sample:0.01|
# EPOCH[759/1000] loss0.010-|Sample:0.01|
# EPOCH[760/1000] loss0.010-|Sample:0.02|
# [TEST]
# {'precision': array([0.00423397]), 'recall': array([0.03737685]), 'ndcg': array([0.02053458])}
# EPOCH[761/1000] loss0.010-|Sample:0.02|
# EPOCH[762/1000] loss0.010-|Sample:0.02|
# EPOCH[763/1000] loss0.010-|Sample:0.01|
# EPOCH[764/1000] loss0.010-|Sample:0.02|
# EPOCH[765/1000] loss0.010-|Sample:0.02|
# EPOCH[766/1000] loss0.010-|Sample:0.01|
# EPOCH[767/1000] loss0.010-|Sample:0.02|
# EPOCH[768/1000] loss0.011-|Sample:0.01|
# EPOCH[769/1000] loss0.010-|Sample:0.02|
# EPOCH[770/1000] loss0.010-|Sample:0.01|
# [TEST]
# {'precision': array([0.00418502]), 'recall': array([0.03715629]), 'ndcg': array([0.02037923])}
# EPOCH[771/1000] loss0.010-|Sample:0.02|
# EPOCH[772/1000] loss0.010-|Sample:0.02|
# EPOCH[773/1000] loss0.010-|Sample:0.01|
# EPOCH[774/1000] loss0.010-|Sample:0.02|
# EPOCH[775/1000] loss0.010-|Sample:0.01|
# EPOCH[776/1000] loss0.010-|Sample:0.01|
# EPOCH[777/1000] loss0.010-|Sample:0.01|
# EPOCH[778/1000] loss0.010-|Sample:0.02|
# EPOCH[779/1000] loss0.010-|Sample:0.01|
# EPOCH[780/1000] loss0.010-|Sample:0.02|
# [TEST]
# {'precision': array([0.00419114]), 'recall': array([0.03712016]), 'ndcg': array([0.02040284])}
# EPOCH[781/1000] loss0.010-|Sample:0.02|
# EPOCH[782/1000] loss0.010-|Sample:0.01|
# EPOCH[783/1000] loss0.010-|Sample:0.02|
# EPOCH[784/1000] loss0.010-|Sample:0.02|
# EPOCH[785/1000] loss0.010-|Sample:0.02|
# EPOCH[786/1000] loss0.010-|Sample:0.01|
# EPOCH[787/1000] loss0.010-|Sample:0.02|
# EPOCH[788/1000] loss0.010-|Sample:0.01|
# EPOCH[789/1000] loss0.010-|Sample:0.01|
# EPOCH[790/1000] loss0.010-|Sample:0.01|
# [TEST]
# {'precision': array([0.0041789]), 'recall': array([0.0369201]), 'ndcg': array([0.02042487])}
# EPOCH[791/1000] loss0.010-|Sample:0.02|
# EPOCH[792/1000] loss0.010-|Sample:0.02|
# EPOCH[793/1000] loss0.010-|Sample:0.02|
# EPOCH[794/1000] loss0.010-|Sample:0.01|
# EPOCH[795/1000] loss0.010-|Sample:0.02|
# EPOCH[796/1000] loss0.010-|Sample:0.02|
# EPOCH[797/1000] loss0.009-|Sample:0.01|
# EPOCH[798/1000] loss0.010-|Sample:0.02|
# EPOCH[799/1000] loss0.010-|Sample:0.01|
# EPOCH[800/1000] loss0.010-|Sample:0.02|
# [TEST]
# {'precision': array([0.00416667]), 'recall': array([0.03701479]), 'ndcg': array([0.02038906])}
# EPOCH[801/1000] loss0.010-|Sample:0.02|
# EPOCH[802/1000] loss0.010-|Sample:0.02|
# EPOCH[803/1000] loss0.010-|Sample:0.01|
# EPOCH[804/1000] loss0.010-|Sample:0.02|
# EPOCH[805/1000] loss0.010-|Sample:0.01|
# EPOCH[806/1000] loss0.009-|Sample:0.01|
# EPOCH[807/1000] loss0.010-|Sample:0.01|
# EPOCH[808/1000] loss0.010-|Sample:0.02|
# EPOCH[809/1000] loss0.010-|Sample:0.01|
# EPOCH[810/1000] loss0.010-|Sample:0.02|
# [TEST]
# {'precision': array([0.00416667]), 'recall': array([0.0369116]), 'ndcg': array([0.02032019])}
# EPOCH[811/1000] loss0.010-|Sample:0.02|
# EPOCH[812/1000] loss0.010-|Sample:0.02|
# EPOCH[813/1000] loss0.010-|Sample:0.01|
# EPOCH[814/1000] loss0.010-|Sample:0.02|
# EPOCH[815/1000] loss0.010-|Sample:0.01|
# EPOCH[816/1000] loss0.010-|Sample:0.02|
# EPOCH[817/1000] loss0.010-|Sample:0.01|
# EPOCH[818/1000] loss0.010-|Sample:0.01|
# EPOCH[819/1000] loss0.010-|Sample:0.01|
# EPOCH[820/1000] loss0.010-|Sample:0.01|
# [TEST]
# {'precision': array([0.00416667]), 'recall': array([0.03660366]), 'ndcg': array([0.02018821])}
# EPOCH[821/1000] loss0.010-|Sample:0.02|
# EPOCH[822/1000] loss0.010-|Sample:0.02|
# EPOCH[823/1000] loss0.010-|Sample:0.01|
# EPOCH[824/1000] loss0.010-|Sample:0.02|
# EPOCH[825/1000] loss0.010-|Sample:0.01|
# EPOCH[826/1000] loss0.010-|Sample:0.01|
# EPOCH[827/1000] loss0.010-|Sample:0.01|
# EPOCH[828/1000] loss0.010-|Sample:0.02|
# EPOCH[829/1000] loss0.010-|Sample:0.01|
# EPOCH[830/1000] loss0.010-|Sample:0.01|
# [TEST]
# {'precision': array([0.00416667]), 'recall': array([0.03665404]), 'ndcg': array([0.02020459])}
# EPOCH[831/1000] loss0.010-|Sample:0.02|
# EPOCH[832/1000] loss0.010-|Sample:0.01|
# EPOCH[833/1000] loss0.010-|Sample:0.01|
# EPOCH[834/1000] loss0.010-|Sample:0.01|
# EPOCH[835/1000] loss0.010-|Sample:0.01|
# EPOCH[836/1000] loss0.010-|Sample:0.01|
# EPOCH[837/1000] loss0.010-|Sample:0.01|
# EPOCH[838/1000] loss0.010-|Sample:0.01|
# EPOCH[839/1000] loss0.009-|Sample:0.01|
# EPOCH[840/1000] loss0.010-|Sample:0.01|
# [TEST]
# {'precision': array([0.00416055]), 'recall': array([0.0368189]), 'ndcg': array([0.01980007])}
# EPOCH[841/1000] loss0.009-|Sample:0.02|
# EPOCH[842/1000] loss0.010-|Sample:0.02|
# EPOCH[843/1000] loss0.010-|Sample:0.01|
# EPOCH[844/1000] loss0.010-|Sample:0.01|
# EPOCH[845/1000] loss0.009-|Sample:0.01|
# EPOCH[846/1000] loss0.010-|Sample:0.02|
# EPOCH[847/1000] loss0.010-|Sample:0.01|
# EPOCH[848/1000] loss0.009-|Sample:0.01|
# EPOCH[849/1000] loss0.010-|Sample:0.01|
# EPOCH[850/1000] loss0.010-|Sample:0.01|
# [TEST]
# {'precision': array([0.00417279]), 'recall': array([0.03684345]), 'ndcg': array([0.01987936])}
# EPOCH[851/1000] loss0.010-|Sample:0.02|
# EPOCH[852/1000] loss0.010-|Sample:0.02|
# EPOCH[853/1000] loss0.009-|Sample:0.01|
# EPOCH[854/1000] loss0.010-|Sample:0.02|
# EPOCH[855/1000] loss0.010-|Sample:0.01|
# EPOCH[856/1000] loss0.010-|Sample:0.02|
# EPOCH[857/1000] loss0.010-|Sample:0.01|
# EPOCH[858/1000] loss0.010-|Sample:0.02|
# EPOCH[859/1000] loss0.010-|Sample:0.01|
# EPOCH[860/1000] loss0.010-|Sample:0.01|
# [TEST]
# {'precision': array([0.00416055]), 'recall': array([0.03668859]), 'ndcg': array([0.01976242])}
# EPOCH[861/1000] loss0.010-|Sample:0.02|
# EPOCH[862/1000] loss0.010-|Sample:0.02|
# EPOCH[863/1000] loss0.010-|Sample:0.01|
# EPOCH[864/1000] loss0.010-|Sample:0.01|
# EPOCH[865/1000] loss0.010-|Sample:0.01|
# EPOCH[866/1000] loss0.010-|Sample:0.01|
# EPOCH[867/1000] loss0.009-|Sample:0.02|
# EPOCH[868/1000] loss0.009-|Sample:0.02|
# EPOCH[869/1000] loss0.010-|Sample:0.01|
# EPOCH[870/1000] loss0.009-|Sample:0.02|
# [TEST]
# {'precision': array([0.00419114]), 'recall': array([0.03687402]), 'ndcg': array([0.01986049])}
# EPOCH[871/1000] loss0.009-|Sample:0.02|
# EPOCH[872/1000] loss0.010-|Sample:0.02|
# EPOCH[873/1000] loss0.009-|Sample:0.02|
# EPOCH[874/1000] loss0.009-|Sample:0.01|
# EPOCH[875/1000] loss0.010-|Sample:0.02|
# EPOCH[876/1000] loss0.009-|Sample:0.01|
# EPOCH[877/1000] loss0.010-|Sample:0.02|
# EPOCH[878/1000] loss0.010-|Sample:0.01|
# EPOCH[879/1000] loss0.009-|Sample:0.01|
# EPOCH[880/1000] loss0.009-|Sample:0.01|
# [TEST]
# {'precision': array([0.00418502]), 'recall': array([0.03700979]), 'ndcg': array([0.01978147])}
# EPOCH[881/1000] loss0.010-|Sample:0.02|
# EPOCH[882/1000] loss0.009-|Sample:0.01|
# EPOCH[883/1000] loss0.010-|Sample:0.01|
# EPOCH[884/1000] loss0.010-|Sample:0.01|
# EPOCH[885/1000] loss0.010-|Sample:0.01|
# EPOCH[886/1000] loss0.010-|Sample:0.01|
# EPOCH[887/1000] loss0.009-|Sample:0.01|
# EPOCH[888/1000] loss0.010-|Sample:0.02|
# EPOCH[889/1000] loss0.010-|Sample:0.01|
# EPOCH[890/1000] loss0.010-|Sample:0.02|
# [TEST]
# {'precision': array([0.00415443]), 'recall': array([0.03661655]), 'ndcg': array([0.01986171])}
# EPOCH[891/1000] loss0.009-|Sample:0.02|
# EPOCH[892/1000] loss0.009-|Sample:0.02|
# EPOCH[893/1000] loss0.009-|Sample:0.02|
# EPOCH[894/1000] loss0.010-|Sample:0.02|
# EPOCH[895/1000] loss0.010-|Sample:0.01|
# EPOCH[896/1000] loss0.009-|Sample:0.02|
# EPOCH[897/1000] loss0.009-|Sample:0.01|
# EPOCH[898/1000] loss0.009-|Sample:0.01|
# EPOCH[899/1000] loss0.009-|Sample:0.01|
# EPOCH[900/1000] loss0.010-|Sample:0.02|
# [TEST]
# {'precision': array([0.00416667]), 'recall': array([0.0371002]), 'ndcg': array([0.01989457])}
# EPOCH[901/1000] loss0.009-|Sample:0.02|
# EPOCH[902/1000] loss0.009-|Sample:0.02|
# EPOCH[903/1000] loss0.009-|Sample:0.01|
# EPOCH[904/1000] loss0.009-|Sample:0.02|
# EPOCH[905/1000] loss0.009-|Sample:0.01|
# EPOCH[906/1000] loss0.010-|Sample:0.01|
# EPOCH[907/1000] loss0.009-|Sample:0.01|
# EPOCH[908/1000] loss0.010-|Sample:0.02|
# EPOCH[909/1000] loss0.010-|Sample:0.02|
# EPOCH[910/1000] loss0.010-|Sample:0.01|
# [TEST]
# {'precision': array([0.00411772]), 'recall': array([0.03657226]), 'ndcg': array([0.01971886])}
# EPOCH[911/1000] loss0.010-|Sample:0.02|
# EPOCH[912/1000] loss0.009-|Sample:0.01|
# EPOCH[913/1000] loss0.009-|Sample:0.01|
# EPOCH[914/1000] loss0.009-|Sample:0.01|
# EPOCH[915/1000] loss0.009-|Sample:0.01|
# EPOCH[916/1000] loss0.010-|Sample:0.01|
# EPOCH[917/1000] loss0.009-|Sample:0.02|
# EPOCH[918/1000] loss0.010-|Sample:0.01|
# EPOCH[919/1000] loss0.009-|Sample:0.02|
# EPOCH[920/1000] loss0.009-|Sample:0.01|
# [TEST]
# {'precision': array([0.00412384]), 'recall': array([0.03651856]), 'ndcg': array([0.01974405])}
# EPOCH[921/1000] loss0.009-|Sample:0.02|
# EPOCH[922/1000] loss0.009-|Sample:0.02|
# EPOCH[923/1000] loss0.010-|Sample:0.01|
# EPOCH[924/1000] loss0.009-|Sample:0.02|
# EPOCH[925/1000] loss0.010-|Sample:0.02|
# EPOCH[926/1000] loss0.009-|Sample:0.01|
# EPOCH[927/1000] loss0.010-|Sample:0.02|
# EPOCH[928/1000] loss0.010-|Sample:0.01|
# EPOCH[929/1000] loss0.009-|Sample:0.02|
# EPOCH[930/1000] loss0.009-|Sample:0.02|
# [TEST]
# {'precision': array([0.0041116]), 'recall': array([0.03644042]), 'ndcg': array([0.0194032])}
# EPOCH[931/1000] loss0.009-|Sample:0.02|
# EPOCH[932/1000] loss0.009-|Sample:0.01|
# EPOCH[933/1000] loss0.009-|Sample:0.02|
# EPOCH[934/1000] loss0.009-|Sample:0.01|
# EPOCH[935/1000] loss0.009-|Sample:0.01|
# EPOCH[936/1000] loss0.009-|Sample:0.01|
# EPOCH[937/1000] loss0.010-|Sample:0.02|
# EPOCH[938/1000] loss0.009-|Sample:0.01|
# EPOCH[939/1000] loss0.009-|Sample:0.01|
# EPOCH[940/1000] loss0.009-|Sample:0.02|
# [TEST]
# {'precision': array([0.00410548]), 'recall': array([0.0361798]), 'ndcg': array([0.01940628])}
# EPOCH[941/1000] loss0.009-|Sample:0.02|
# EPOCH[942/1000] loss0.009-|Sample:0.01|
# EPOCH[943/1000] loss0.009-|Sample:0.02|
# EPOCH[944/1000] loss0.009-|Sample:0.01|
# EPOCH[945/1000] loss0.009-|Sample:0.02|
# EPOCH[946/1000] loss0.009-|Sample:0.01|
# EPOCH[947/1000] loss0.009-|Sample:0.02|
# EPOCH[948/1000] loss0.009-|Sample:0.01|
# EPOCH[949/1000] loss0.009-|Sample:0.01|
# EPOCH[950/1000] loss0.009-|Sample:0.02|
# [TEST]
# {'precision': array([0.00412384]), 'recall': array([0.03639395]), 'ndcg': array([0.01950504])}
# EPOCH[951/1000] loss0.009-|Sample:0.02|
# EPOCH[952/1000] loss0.009-|Sample:0.02|
# EPOCH[953/1000] loss0.009-|Sample:0.01|
# EPOCH[954/1000] loss0.009-|Sample:0.01|
# EPOCH[955/1000] loss0.009-|Sample:0.01|
# EPOCH[956/1000] loss0.009-|Sample:0.01|
# EPOCH[957/1000] loss0.009-|Sample:0.01|
# EPOCH[958/1000] loss0.009-|Sample:0.01|
# EPOCH[959/1000] loss0.009-|Sample:0.01|
# EPOCH[960/1000] loss0.009-|Sample:0.01|
# [TEST]
# {'precision': array([0.00414219]), 'recall': array([0.03635345]), 'ndcg': array([0.01942287])}
# EPOCH[961/1000] loss0.009-|Sample:0.02|
# EPOCH[962/1000] loss0.009-|Sample:0.02|
# EPOCH[963/1000] loss0.009-|Sample:0.01|
# EPOCH[964/1000] loss0.009-|Sample:0.01|
# EPOCH[965/1000] loss0.009-|Sample:0.01|
# EPOCH[966/1000] loss0.009-|Sample:0.02|
# EPOCH[967/1000] loss0.009-|Sample:0.01|
# EPOCH[968/1000] loss0.009-|Sample:0.02|
# EPOCH[969/1000] loss0.009-|Sample:0.02|
# EPOCH[970/1000] loss0.009-|Sample:0.01|
# [TEST]
# {'precision': array([0.00406877]), 'recall': array([0.03584766]), 'ndcg': array([0.01919777])}
# EPOCH[971/1000] loss0.009-|Sample:0.02|
# EPOCH[972/1000] loss0.009-|Sample:0.01|
# EPOCH[973/1000] loss0.009-|Sample:0.02|
# EPOCH[974/1000] loss0.009-|Sample:0.01|
# EPOCH[975/1000] loss0.009-|Sample:0.01|
# EPOCH[976/1000] loss0.009-|Sample:0.01|
# EPOCH[977/1000] loss0.009-|Sample:0.02|
# EPOCH[978/1000] loss0.009-|Sample:0.02|
# EPOCH[979/1000] loss0.009-|Sample:0.01|
# EPOCH[980/1000] loss0.009-|Sample:0.02|
# [TEST]
# {'precision': array([0.00414219]), 'recall': array([0.0364008]), 'ndcg': array([0.01927881])}
# EPOCH[981/1000] loss0.009-|Sample:0.02|
# EPOCH[982/1000] loss0.009-|Sample:0.02|
# EPOCH[983/1000] loss0.009-|Sample:0.02|
# EPOCH[984/1000] loss0.009-|Sample:0.01|
# EPOCH[985/1000] loss0.009-|Sample:0.01|
# EPOCH[986/1000] loss0.009-|Sample:0.01|
# EPOCH[987/1000] loss0.009-|Sample:0.02|
# EPOCH[988/1000] loss0.009-|Sample:0.01|
# EPOCH[989/1000] loss0.009-|Sample:0.02|
# EPOCH[990/1000] loss0.009-|Sample:0.01|
# [TEST]
# {'precision': array([0.00416055]), 'recall': array([0.03674037]), 'ndcg': array([0.01939764])}
# EPOCH[991/1000] loss0.009-|Sample:0.02|
# EPOCH[992/1000] loss0.009-|Sample:0.02|
# EPOCH[993/1000] loss0.009-|Sample:0.01|
# EPOCH[994/1000] loss0.009-|Sample:0.02|
# EPOCH[995/1000] loss0.009-|Sample:0.01|
# EPOCH[996/1000] loss0.009-|Sample:0.02|
# EPOCH[997/1000] loss0.009-|Sample:0.01|
# EPOCH[998/1000] loss0.010-|Sample:0.01|
# EPOCH[999/1000] loss0.009-|Sample:0.01|
# EPOCH[1000/1000] loss0.009-|Sample:0.01|
