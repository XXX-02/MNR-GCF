# %%
# %load main.py
import world
import utils
from world import cprint
import torch
import numpy as np
from tensorboardX import SummaryWriter
import time
import Procedure
from os.path import join
# ==============================
utils.set_seed(world.seed)
print(">>SEED:", world.seed)
# ==============================
import register
from register import dataset

Recmodel = register.MODELS[world.model_name](world.config, dataset)
Recmodel = Recmodel.to(world.device)
bpr = utils.BPRLoss(Recmodel, world.config)

weight_file = utils.getFileName()
print(f"load and save to {weight_file}")
if world.LOAD:
    try:
        Recmodel.load_state_dict(torch.load(weight_file,map_location=torch.device('cpu')))
        world.cprint(f"loaded model weights from {weight_file}")
    except FileNotFoundError:
        print(f"{weight_file} not exists, start from beginning")
Neg_k = 1

# init tensorboard
if world.tensorboard:
    w : SummaryWriter = SummaryWriter(
                                    join(world.BOARD_PATH, time.strftime("%m-%d-%Hh%Mm%Ss-") + "-" + world.comment)
                                    )
else:
    w = None
    world.cprint("not enable tensorflowboard")

try:
    for epoch in range(world.TRAIN_epochs):
        start = time.time()
        if epoch %10 == 0:
            cprint("[TEST]")
            Procedure.Test(dataset, Recmodel, epoch, w, world.config['multicore'])
        output_information = Procedure.BPR_train_original(dataset, Recmodel, bpr, epoch, neg_k=Neg_k,w=w)
        print(f'EPOCH[{epoch+1}/{world.TRAIN_epochs}] {output_information}')
        torch.save(Recmodel.state_dict(), weight_file)
finally:
    if world.tensorboard:
        w.close()
# Out:
# >>SEED: 2020
# loading [../data/gowalla]
# 810128 interactions for training
# 217242 interactions for testing
# gowalla Sparsity : 0.0008396216228570436
# gowalla is ready to go
# ===========config================
# {'A_n_fold': 100,
#  'A_split': False,
#  'bigdata': False,
#  'bpr_batch_size': 2048,
#  'decay': 0.0001,
#  'dropout': 0,
#  'keep_prob': 0.6,
#  'latent_dim_rec': 64,
#  'lightGCN_n_layers': 3,
#  'lr': 0.001,
#  'multicore': 1,
#  'pretrain': 0,
#  'test_u_batch_size': 100}
# cores for test: 24
# comment: lgn
# tensorboard: 1
# LOAD: 0
# Weight path: ./checkpoints
# Test Topks: [20]
# using bpr loss
# ===========end===================
# use NORMAL distribution initilizer
# loading adjacency matrix
# successfully loaded heterogeneous graph ...
# don't split the matrix
# loading adjacency matrix
# successfully loaded homogeneous graph ...
# don't split the matrix
# loading degree weight
# successfully loaded heterogeneous degree weight ...
# lgn is already to go(dropout:0)
# load and save to /home/user1/Larry/FGCF/runs/code/checkpoints/lgn-gowalla-3-64.pth.tar
# [TEST]
# {'precision': array([0.00024114]), 'recall': array([0.00075566]), 'ndcg': array([0.000482])}
# EPOCH[1/1000] loss0.473-|Sample:0.10|
# EPOCH[2/1000] loss0.208-|Sample:0.10|
# EPOCH[3/1000] loss0.150-|Sample:0.10|
# EPOCH[4/1000] loss0.123-|Sample:0.10|
# EPOCH[5/1000] loss0.108-|Sample:0.09|
# EPOCH[6/1000] loss0.096-|Sample:0.10|
# EPOCH[7/1000] loss0.088-|Sample:0.10|
# EPOCH[8/1000] loss0.082-|Sample:0.10|
# EPOCH[9/1000] loss0.078-|Sample:0.10|
# EPOCH[10/1000] loss0.074-|Sample:0.10|
# [TEST]
# {'precision': array([0.03706042]), 'recall': array([0.11846086]), 'ndcg': array([0.10206943])}
# EPOCH[11/1000] loss0.070-|Sample:0.09|
# EPOCH[12/1000] loss0.067-|Sample:0.10|
# EPOCH[13/1000] loss0.064-|Sample:0.10|
# EPOCH[14/1000] loss0.062-|Sample:0.10|
# EPOCH[15/1000] loss0.060-|Sample:0.10|
# EPOCH[16/1000] loss0.058-|Sample:0.10|
# EPOCH[17/1000] loss0.055-|Sample:0.10|
# EPOCH[18/1000] loss0.054-|Sample:0.10|
# EPOCH[19/1000] loss0.053-|Sample:0.10|
# EPOCH[20/1000] loss0.052-|Sample:0.10|
# [TEST]
# {'precision': array([0.04068759]), 'recall': array([0.13059776]), 'ndcg': array([0.1123605])}
# EPOCH[21/1000] loss0.050-|Sample:0.10|
# EPOCH[22/1000] loss0.049-|Sample:0.10|
# EPOCH[23/1000] loss0.047-|Sample:0.10|
# EPOCH[24/1000] loss0.046-|Sample:0.10|
# EPOCH[25/1000] loss0.045-|Sample:0.10|
# EPOCH[26/1000] loss0.044-|Sample:0.10|
# EPOCH[27/1000] loss0.043-|Sample:0.10|
# EPOCH[28/1000] loss0.043-|Sample:0.10|
# EPOCH[29/1000] loss0.042-|Sample:0.10|
# EPOCH[30/1000] loss0.041-|Sample:0.10|
# [TEST]
# {'precision': array([0.04290475]), 'recall': array([0.13844668]), 'ndcg': array([0.1191159])}
# EPOCH[31/1000] loss0.040-|Sample:0.10|
# EPOCH[32/1000] loss0.040-|Sample:0.10|
# EPOCH[33/1000] loss0.039-|Sample:0.10|
# EPOCH[34/1000] loss0.038-|Sample:0.10|
# EPOCH[35/1000] loss0.037-|Sample:0.10|
# EPOCH[36/1000] loss0.037-|Sample:0.10|
# EPOCH[37/1000] loss0.036-|Sample:0.10|
# EPOCH[38/1000] loss0.036-|Sample:0.10|
# EPOCH[39/1000] loss0.035-|Sample:0.10|
# EPOCH[40/1000] loss0.035-|Sample:0.10|
# [TEST]
# {'precision': array([0.04464633]), 'recall': array([0.14528056]), 'ndcg': array([0.12435872])}
# EPOCH[41/1000] loss0.034-|Sample:0.09|
# EPOCH[42/1000] loss0.033-|Sample:0.10|
# EPOCH[43/1000] loss0.033-|Sample:0.10|
# EPOCH[44/1000] loss0.033-|Sample:0.10|
# EPOCH[45/1000] loss0.033-|Sample:0.10|
# EPOCH[46/1000] loss0.032-|Sample:0.10|
# EPOCH[47/1000] loss0.032-|Sample:0.10|
# EPOCH[48/1000] loss0.031-|Sample:0.10|
# EPOCH[49/1000] loss0.031-|Sample:0.10|
# EPOCH[50/1000] loss0.030-|Sample:0.10|
# [TEST]
# {'precision': array([0.04604796]), 'recall': array([0.14991416]), 'ndcg': array([0.1284795])}
# EPOCH[51/1000] loss0.030-|Sample:0.10|
# EPOCH[52/1000] loss0.029-|Sample:0.10|
# EPOCH[53/1000] loss0.030-|Sample:0.10|
# EPOCH[54/1000] loss0.029-|Sample:0.11|
# EPOCH[55/1000] loss0.029-|Sample:0.10|
# EPOCH[56/1000] loss0.028-|Sample:0.10|
# EPOCH[57/1000] loss0.028-|Sample:0.10|
# EPOCH[58/1000] loss0.028-|Sample:0.10|
# EPOCH[59/1000] loss0.028-|Sample:0.10|
# EPOCH[60/1000] loss0.027-|Sample:0.10|
# [TEST]
# {'precision': array([0.04697736]), 'recall': array([0.15325908]), 'ndcg': array([0.1313489])}
# EPOCH[61/1000] loss0.027-|Sample:0.10|
# EPOCH[62/1000] loss0.027-|Sample:0.10|
# EPOCH[63/1000] loss0.026-|Sample:0.10|
# EPOCH[64/1000] loss0.026-|Sample:0.10|
# EPOCH[65/1000] loss0.026-|Sample:0.10|
# EPOCH[66/1000] loss0.025-|Sample:0.10|
# EPOCH[67/1000] loss0.026-|Sample:0.10|
# EPOCH[68/1000] loss0.025-|Sample:0.10|
# EPOCH[69/1000] loss0.025-|Sample:0.10|
# EPOCH[70/1000] loss0.025-|Sample:0.10|
# [TEST]
# {'precision': array([0.04791513]), 'recall': array([0.15676947]), 'ndcg': array([0.13385436])}
# EPOCH[71/1000] loss0.025-|Sample:0.09|
# EPOCH[72/1000] loss0.024-|Sample:0.10|
# EPOCH[73/1000] loss0.024-|Sample:0.10|
# EPOCH[74/1000] loss0.024-|Sample:0.10|
# EPOCH[75/1000] loss0.024-|Sample:0.10|
# EPOCH[76/1000] loss0.023-|Sample:0.10|
# EPOCH[77/1000] loss0.023-|Sample:0.10|
# EPOCH[78/1000] loss0.023-|Sample:0.10|
# EPOCH[79/1000] loss0.023-|Sample:0.11|
# EPOCH[80/1000] loss0.023-|Sample:0.10|
# [TEST]
# {'precision': array([0.04869549]), 'recall': array([0.15914708]), 'ndcg': array([0.1359953])}
# EPOCH[81/1000] loss0.022-|Sample:0.10|
# EPOCH[82/1000] loss0.022-|Sample:0.10|
# EPOCH[83/1000] loss0.022-|Sample:0.10|
# EPOCH[84/1000] loss0.022-|Sample:0.10|
# EPOCH[85/1000] loss0.022-|Sample:0.10|
# EPOCH[86/1000] loss0.022-|Sample:0.10|
# EPOCH[87/1000] loss0.021-|Sample:0.10|
# EPOCH[88/1000] loss0.021-|Sample:0.10|
# EPOCH[89/1000] loss0.021-|Sample:0.10|
# EPOCH[90/1000] loss0.021-|Sample:0.11|
# [TEST]
# {'precision': array([0.04947753]), 'recall': array([0.16167448]), 'ndcg': array([0.13818508])}
# EPOCH[91/1000] loss0.021-|Sample:0.10|
# EPOCH[92/1000] loss0.021-|Sample:0.09|
# EPOCH[93/1000] loss0.021-|Sample:0.10|
# EPOCH[94/1000] loss0.021-|Sample:0.10|
# EPOCH[95/1000] loss0.021-|Sample:0.10|
# EPOCH[96/1000] loss0.020-|Sample:0.10|
# EPOCH[97/1000] loss0.020-|Sample:0.10|
# EPOCH[98/1000] loss0.020-|Sample:0.10|
# EPOCH[99/1000] loss0.020-|Sample:0.10|
# EPOCH[100/1000] loss0.020-|Sample:0.10|
# [TEST]
# {'precision': array([0.05]), 'recall': array([0.1639506]), 'ndcg': array([0.1398828])}
# EPOCH[101/1000] loss0.019-|Sample:0.09|
# EPOCH[102/1000] loss0.020-|Sample:0.10|
# EPOCH[103/1000] loss0.019-|Sample:0.10|
# EPOCH[104/1000] loss0.019-|Sample:0.10|
# EPOCH[105/1000] loss0.020-|Sample:0.10|
# EPOCH[106/1000] loss0.019-|Sample:0.10|
# EPOCH[107/1000] loss0.019-|Sample:0.10|
# EPOCH[108/1000] loss0.019-|Sample:0.10|
# EPOCH[109/1000] loss0.019-|Sample:0.10|
# EPOCH[110/1000] loss0.019-|Sample:0.10|
# [TEST]
# {'precision': array([0.0504287]), 'recall': array([0.16528211]), 'ndcg': array([0.14125379])}
# EPOCH[111/1000] loss0.018-|Sample:0.10|
# EPOCH[112/1000] loss0.018-|Sample:0.10|
# EPOCH[113/1000] loss0.018-|Sample:0.10|
# EPOCH[114/1000] loss0.018-|Sample:0.10|
# EPOCH[115/1000] loss0.018-|Sample:0.10|
# EPOCH[116/1000] loss0.018-|Sample:0.10|
# EPOCH[117/1000] loss0.018-|Sample:0.10|
# EPOCH[118/1000] loss0.018-|Sample:0.10|
# EPOCH[119/1000] loss0.018-|Sample:0.10|
# EPOCH[120/1000] loss0.018-|Sample:0.10|
# [TEST]
# {'precision': array([0.05084065]), 'recall': array([0.16646523]), 'ndcg': array([0.14245706])}
# EPOCH[121/1000] loss0.018-|Sample:0.10|
# EPOCH[122/1000] loss0.017-|Sample:0.10|
# EPOCH[123/1000] loss0.017-|Sample:0.10|
# EPOCH[124/1000] loss0.017-|Sample:0.10|
# EPOCH[125/1000] loss0.018-|Sample:0.10|
# EPOCH[126/1000] loss0.017-|Sample:0.10|
# EPOCH[127/1000] loss0.017-|Sample:0.09|
# EPOCH[128/1000] loss0.017-|Sample:0.10|
# EPOCH[129/1000] loss0.017-|Sample:0.10|
# EPOCH[130/1000] loss0.017-|Sample:0.11|
# [TEST]
# {'precision': array([0.05136982]), 'recall': array([0.16855828]), 'ndcg': array([0.14387418])}
# EPOCH[131/1000] loss0.017-|Sample:0.10|
# EPOCH[132/1000] loss0.017-|Sample:0.11|
# EPOCH[133/1000] loss0.017-|Sample:0.10|
# EPOCH[134/1000] loss0.017-|Sample:0.10|
# EPOCH[135/1000] loss0.016-|Sample:0.10|
# EPOCH[136/1000] loss0.016-|Sample:0.10|
# EPOCH[137/1000] loss0.016-|Sample:0.10|
# EPOCH[138/1000] loss0.016-|Sample:0.10|
# EPOCH[139/1000] loss0.016-|Sample:0.10|
# EPOCH[140/1000] loss0.016-|Sample:0.10|
# [TEST]
# {'precision': array([0.05163273]), 'recall': array([0.16920635]), 'ndcg': array([0.14459188])}
# EPOCH[141/1000] loss0.016-|Sample:0.10|
# EPOCH[142/1000] loss0.016-|Sample:0.10|
# EPOCH[143/1000] loss0.016-|Sample:0.10|
# EPOCH[144/1000] loss0.016-|Sample:0.10|
# EPOCH[145/1000] loss0.016-|Sample:0.10|
# EPOCH[146/1000] loss0.016-|Sample:0.10|
# EPOCH[147/1000] loss0.016-|Sample:0.10|
# EPOCH[148/1000] loss0.016-|Sample:0.10|
# EPOCH[149/1000] loss0.016-|Sample:0.10|
# EPOCH[150/1000] loss0.016-|Sample:0.10|
# [TEST]
# {'precision': array([0.05199779]), 'recall': array([0.17037166]), 'ndcg': array([0.14549446])}
# EPOCH[151/1000] loss0.016-|Sample:0.10|
# EPOCH[152/1000] loss0.016-|Sample:0.10|
# EPOCH[153/1000] loss0.016-|Sample:0.10|
# EPOCH[154/1000] loss0.015-|Sample:0.10|
# EPOCH[155/1000] loss0.015-|Sample:0.10|
# EPOCH[156/1000] loss0.016-|Sample:0.10|
# EPOCH[157/1000] loss0.015-|Sample:0.10|
# EPOCH[158/1000] loss0.015-|Sample:0.10|
# EPOCH[159/1000] loss0.016-|Sample:0.10|
# EPOCH[160/1000] loss0.015-|Sample:0.10|
# [TEST]
# {'precision': array([0.05228917]), 'recall': array([0.17131735]), 'ndcg': array([0.14636578])}
# EPOCH[161/1000] loss0.015-|Sample:0.10|
# EPOCH[162/1000] loss0.015-|Sample:0.10|
# EPOCH[163/1000] loss0.015-|Sample:0.10|
# EPOCH[164/1000] loss0.015-|Sample:0.10|
# EPOCH[165/1000] loss0.015-|Sample:0.10|
# EPOCH[166/1000] loss0.015-|Sample:0.10|
# EPOCH[167/1000] loss0.015-|Sample:0.10|
# EPOCH[168/1000] loss0.015-|Sample:0.10|
# EPOCH[169/1000] loss0.015-|Sample:0.10|
# EPOCH[170/1000] loss0.015-|Sample:0.10|
# [TEST]
# {'precision': array([0.0525906]), 'recall': array([0.17176152]), 'ndcg': array([0.14693851])}
# EPOCH[171/1000] loss0.015-|Sample:0.10|
# EPOCH[172/1000] loss0.014-|Sample:0.10|
# EPOCH[173/1000] loss0.014-|Sample:0.10|
# EPOCH[174/1000] loss0.015-|Sample:0.10|
# EPOCH[175/1000] loss0.014-|Sample:0.10|
# EPOCH[176/1000] loss0.014-|Sample:0.10|
# EPOCH[177/1000] loss0.014-|Sample:0.10|
# EPOCH[178/1000] loss0.014-|Sample:0.10|
# EPOCH[179/1000] loss0.014-|Sample:0.10|
# EPOCH[180/1000] loss0.014-|Sample:0.10|
# [TEST]
# {'precision': array([0.05293891]), 'recall': array([0.17314703]), 'ndcg': array([0.14800373])}
# EPOCH[181/1000] loss0.014-|Sample:0.09|
# EPOCH[182/1000] loss0.014-|Sample:0.10|
# EPOCH[183/1000] loss0.014-|Sample:0.10|
# EPOCH[184/1000] loss0.014-|Sample:0.10|
# EPOCH[185/1000] loss0.014-|Sample:0.10|
# EPOCH[186/1000] loss0.014-|Sample:0.10|
# EPOCH[187/1000] loss0.014-|Sample:0.10|
# EPOCH[188/1000] loss0.014-|Sample:0.10|
# EPOCH[189/1000] loss0.014-|Sample:0.10|
# EPOCH[190/1000] loss0.014-|Sample:0.10|
# [TEST]
# {'precision': array([0.05298915]), 'recall': array([0.17334204]), 'ndcg': array([0.14818821])}
# EPOCH[191/1000] loss0.014-|Sample:0.10|
# EPOCH[192/1000] loss0.014-|Sample:0.10|
# EPOCH[193/1000] loss0.014-|Sample:0.10|
# EPOCH[194/1000] loss0.014-|Sample:0.10|
# EPOCH[195/1000] loss0.014-|Sample:0.10|
# EPOCH[196/1000] loss0.014-|Sample:0.10|
# EPOCH[197/1000] loss0.014-|Sample:0.11|
# EPOCH[198/1000] loss0.014-|Sample:0.11|
# EPOCH[199/1000] loss0.014-|Sample:0.10|
# EPOCH[200/1000] loss0.014-|Sample:0.10|
# [TEST]
# {'precision': array([0.05341784]), 'recall': array([0.17471033]), 'ndcg': array([0.14923492])}
# EPOCH[201/1000] loss0.014-|Sample:0.10|
# EPOCH[202/1000] loss0.014-|Sample:0.10|
# EPOCH[203/1000] loss0.013-|Sample:0.11|
# EPOCH[204/1000] loss0.013-|Sample:0.10|
# EPOCH[205/1000] loss0.013-|Sample:0.10|
# EPOCH[206/1000] loss0.013-|Sample:0.10|
# EPOCH[207/1000] loss0.013-|Sample:0.10|
# EPOCH[208/1000] loss0.013-|Sample:0.10|
# EPOCH[209/1000] loss0.013-|Sample:0.10|
# EPOCH[210/1000] loss0.013-|Sample:0.10|
# [TEST]
# {'precision': array([0.05366401]), 'recall': array([0.17560293]), 'ndcg': array([0.14973959])}
# EPOCH[211/1000] loss0.013-|Sample:0.10|
# EPOCH[212/1000] loss0.013-|Sample:0.10|
# EPOCH[213/1000] loss0.013-|Sample:0.11|
# EPOCH[214/1000] loss0.013-|Sample:0.10|
# EPOCH[215/1000] loss0.013-|Sample:0.10|
# EPOCH[216/1000] loss0.013-|Sample:0.10|
# EPOCH[217/1000] loss0.013-|Sample:0.09|
# EPOCH[218/1000] loss0.013-|Sample:0.10|
# EPOCH[219/1000] loss0.013-|Sample:0.10|
# EPOCH[220/1000] loss0.013-|Sample:0.10|
# [TEST]
# {'precision': array([0.05379295]), 'recall': array([0.17607569]), 'ndcg': array([0.15027598])}
# EPOCH[221/1000] loss0.013-|Sample:0.12|
# EPOCH[222/1000] loss0.013-|Sample:0.10|
# EPOCH[223/1000] loss0.013-|Sample:0.10|
# EPOCH[224/1000] loss0.013-|Sample:0.10|
# EPOCH[225/1000] loss0.013-|Sample:0.10|
# EPOCH[226/1000] loss0.013-|Sample:0.10|
# EPOCH[227/1000] loss0.013-|Sample:0.10|
# EPOCH[228/1000] loss0.013-|Sample:0.10|
# EPOCH[229/1000] loss0.013-|Sample:0.10|
# EPOCH[230/1000] loss0.013-|Sample:0.10|
# [TEST]
# {'precision': array([0.05403075]), 'recall': array([0.17695695]), 'ndcg': array([0.15112693])}
# EPOCH[231/1000] loss0.013-|Sample:0.10|
# EPOCH[232/1000] loss0.013-|Sample:0.10|
# EPOCH[233/1000] loss0.013-|Sample:0.10|
# EPOCH[234/1000] loss0.013-|Sample:0.10|
# EPOCH[235/1000] loss0.013-|Sample:0.10|
# EPOCH[236/1000] loss0.013-|Sample:0.10|
# EPOCH[237/1000] loss0.013-|Sample:0.10|
# EPOCH[238/1000] loss0.013-|Sample:0.10|
# EPOCH[239/1000] loss0.013-|Sample:0.10|
# EPOCH[240/1000] loss0.012-|Sample:0.11|
# [TEST]
# {'precision': array([0.0541061]), 'recall': array([0.17695551]), 'ndcg': array([0.15150411])}
# EPOCH[241/1000] loss0.013-|Sample:0.10|
# EPOCH[242/1000] loss0.013-|Sample:0.10|
# EPOCH[243/1000] loss0.012-|Sample:0.10|
# EPOCH[244/1000] loss0.012-|Sample:0.10|
# EPOCH[245/1000] loss0.012-|Sample:0.10|
# EPOCH[246/1000] loss0.012-|Sample:0.10|
# EPOCH[247/1000] loss0.013-|Sample:0.10|
# EPOCH[248/1000] loss0.013-|Sample:0.10|
# EPOCH[249/1000] loss0.012-|Sample:0.10|
# EPOCH[250/1000] loss0.013-|Sample:0.10|
# [TEST]
# {'precision': array([0.05426184]), 'recall': array([0.17749524]), 'ndcg': array([0.151816])}
# EPOCH[251/1000] loss0.013-|Sample:0.09|
# EPOCH[252/1000] loss0.013-|Sample:0.10|
# EPOCH[253/1000] loss0.012-|Sample:0.10|
# EPOCH[254/1000] loss0.012-|Sample:0.10|
# EPOCH[255/1000] loss0.012-|Sample:0.10|
# EPOCH[256/1000] loss0.012-|Sample:0.10|
# EPOCH[257/1000] loss0.012-|Sample:0.10|
# EPOCH[258/1000] loss0.012-|Sample:0.10|
# EPOCH[259/1000] loss0.013-|Sample:0.10|
# EPOCH[260/1000] loss0.012-|Sample:0.10|
# [TEST]
# {'precision': array([0.05439246]), 'recall': array([0.17760954]), 'ndcg': array([0.15201363])}
# EPOCH[261/1000] loss0.012-|Sample:0.10|
# EPOCH[262/1000] loss0.012-|Sample:0.10|
# EPOCH[263/1000] loss0.012-|Sample:0.10|
# EPOCH[264/1000] loss0.012-|Sample:0.10|
# EPOCH[265/1000] loss0.012-|Sample:0.10|
# EPOCH[266/1000] loss0.012-|Sample:0.10|
# EPOCH[267/1000] loss0.012-|Sample:0.10|
# EPOCH[268/1000] loss0.012-|Sample:0.10|
# EPOCH[269/1000] loss0.012-|Sample:0.10|
# EPOCH[270/1000] loss0.012-|Sample:0.10|
# [TEST]
# {'precision': array([0.0544427]), 'recall': array([0.17789794]), 'ndcg': array([0.15222033])}
# EPOCH[271/1000] loss0.012-|Sample:0.10|
# EPOCH[272/1000] loss0.012-|Sample:0.10|
# EPOCH[273/1000] loss0.012-|Sample:0.10|
# EPOCH[274/1000] loss0.012-|Sample:0.10|
# EPOCH[275/1000] loss0.012-|Sample:0.11|
# EPOCH[276/1000] loss0.012-|Sample:0.10|
# EPOCH[277/1000] loss0.012-|Sample:0.10|
# EPOCH[278/1000] loss0.012-|Sample:0.10|
# EPOCH[279/1000] loss0.012-|Sample:0.10|
# EPOCH[280/1000] loss0.012-|Sample:0.10|
# [TEST]
# {'precision': array([0.05444437]), 'recall': array([0.17767412]), 'ndcg': array([0.15219817])}
# EPOCH[281/1000] loss0.012-|Sample:0.10|
# EPOCH[282/1000] loss0.012-|Sample:0.11|
# EPOCH[283/1000] loss0.012-|Sample:0.10|
# EPOCH[284/1000] loss0.012-|Sample:0.09|
# EPOCH[285/1000] loss0.012-|Sample:0.10|
# EPOCH[286/1000] loss0.012-|Sample:0.10|
# EPOCH[287/1000] loss0.012-|Sample:0.10|
# EPOCH[288/1000] loss0.012-|Sample:0.10|
# EPOCH[289/1000] loss0.012-|Sample:0.10|
# EPOCH[290/1000] loss0.012-|Sample:0.10|
# [TEST]
# {'precision': array([0.05445442]), 'recall': array([0.1780587]), 'ndcg': array([0.15241135])}
# EPOCH[291/1000] loss0.012-|Sample:0.11|
# EPOCH[292/1000] loss0.012-|Sample:0.10|
# EPOCH[293/1000] loss0.012-|Sample:0.10|
# EPOCH[294/1000] loss0.012-|Sample:0.10|
# EPOCH[295/1000] loss0.012-|Sample:0.10|
# EPOCH[296/1000] loss0.012-|Sample:0.10|
# EPOCH[297/1000] loss0.012-|Sample:0.10|
# EPOCH[298/1000] loss0.012-|Sample:0.10|
# EPOCH[299/1000] loss0.012-|Sample:0.10|
# EPOCH[300/1000] loss0.012-|Sample:0.10|
# [TEST]
# {'precision': array([0.05473575]), 'recall': array([0.17914848]), 'ndcg': array([0.15280121])}
# EPOCH[301/1000] loss0.012-|Sample:0.10|
# EPOCH[302/1000] loss0.012-|Sample:0.10|
# EPOCH[303/1000] loss0.012-|Sample:0.10|
# EPOCH[304/1000] loss0.012-|Sample:0.10|
# EPOCH[305/1000] loss0.012-|Sample:0.10|
# EPOCH[306/1000] loss0.012-|Sample:0.09|
# EPOCH[307/1000] loss0.012-|Sample:0.10|
# EPOCH[308/1000] loss0.012-|Sample:0.10|
# EPOCH[309/1000] loss0.012-|Sample:0.09|
# EPOCH[310/1000] loss0.012-|Sample:0.10|
# [TEST]
# {'precision': array([0.05479101]), 'recall': array([0.17920279]), 'ndcg': array([0.15276874])}
# EPOCH[311/1000] loss0.012-|Sample:0.10|
# EPOCH[312/1000] loss0.012-|Sample:0.10|
# EPOCH[313/1000] loss0.012-|Sample:0.10|
# EPOCH[314/1000] loss0.012-|Sample:0.10|
# EPOCH[315/1000] loss0.011-|Sample:0.10|
# EPOCH[316/1000] loss0.011-|Sample:0.10|
# EPOCH[317/1000] loss0.012-|Sample:0.10|
# EPOCH[318/1000] loss0.012-|Sample:0.10|
# EPOCH[319/1000] loss0.012-|Sample:0.10|
# EPOCH[320/1000] loss0.012-|Sample:0.10|
# [TEST]
# {'precision': array([0.05481948]), 'recall': array([0.17905891]), 'ndcg': array([0.15275829])}
# EPOCH[321/1000] loss0.011-|Sample:0.10|
# EPOCH[322/1000] loss0.012-|Sample:0.10|
# EPOCH[323/1000] loss0.011-|Sample:0.10|
# EPOCH[324/1000] loss0.012-|Sample:0.10|
# EPOCH[325/1000] loss0.011-|Sample:0.10|
# EPOCH[326/1000] loss0.012-|Sample:0.10|
# EPOCH[327/1000] loss0.012-|Sample:0.10|
# EPOCH[328/1000] loss0.012-|Sample:0.10|
# EPOCH[329/1000] loss0.011-|Sample:0.10|
# EPOCH[330/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05489986]), 'recall': array([0.17948897]), 'ndcg': array([0.15289372])}
# EPOCH[331/1000] loss0.011-|Sample:0.09|
# EPOCH[332/1000] loss0.011-|Sample:0.10|
# EPOCH[333/1000] loss0.011-|Sample:0.10|
# EPOCH[334/1000] loss0.011-|Sample:0.10|
# EPOCH[335/1000] loss0.011-|Sample:0.10|
# EPOCH[336/1000] loss0.011-|Sample:0.10|
# EPOCH[337/1000] loss0.011-|Sample:0.10|
# EPOCH[338/1000] loss0.012-|Sample:0.10|
# EPOCH[339/1000] loss0.011-|Sample:0.10|
# EPOCH[340/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05495847]), 'recall': array([0.17959131]), 'ndcg': array([0.15339323])}
# EPOCH[341/1000] loss0.011-|Sample:0.10|
# EPOCH[342/1000] loss0.011-|Sample:0.10|
# EPOCH[343/1000] loss0.011-|Sample:0.10|
# EPOCH[344/1000] loss0.011-|Sample:0.10|
# EPOCH[345/1000] loss0.011-|Sample:0.10|
# EPOCH[346/1000] loss0.011-|Sample:0.10|
# EPOCH[347/1000] loss0.011-|Sample:0.10|
# EPOCH[348/1000] loss0.011-|Sample:0.10|
# EPOCH[349/1000] loss0.011-|Sample:0.10|
# EPOCH[350/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05503718]), 'recall': array([0.17968422]), 'ndcg': array([0.15329251])}
# EPOCH[351/1000] loss0.011-|Sample:0.10|
# EPOCH[352/1000] loss0.011-|Sample:0.10|
# EPOCH[353/1000] loss0.011-|Sample:0.10|
# EPOCH[354/1000] loss0.011-|Sample:0.10|
# EPOCH[355/1000] loss0.011-|Sample:0.10|
# EPOCH[356/1000] loss0.011-|Sample:0.10|
# EPOCH[357/1000] loss0.011-|Sample:0.10|
# EPOCH[358/1000] loss0.011-|Sample:0.10|
# EPOCH[359/1000] loss0.011-|Sample:0.10|
# EPOCH[360/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05509914]), 'recall': array([0.18009018]), 'ndcg': array([0.15352479])}
# EPOCH[361/1000] loss0.011-|Sample:0.10|
# EPOCH[362/1000] loss0.011-|Sample:0.10|
# EPOCH[363/1000] loss0.011-|Sample:0.10|
# EPOCH[364/1000] loss0.011-|Sample:0.10|
# EPOCH[365/1000] loss0.011-|Sample:0.10|
# EPOCH[366/1000] loss0.011-|Sample:0.10|
# EPOCH[367/1000] loss0.011-|Sample:0.10|
# EPOCH[368/1000] loss0.011-|Sample:0.10|
# EPOCH[369/1000] loss0.011-|Sample:0.10|
# EPOCH[370/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05531013]), 'recall': array([0.18051605]), 'ndcg': array([0.15365529])}
# EPOCH[371/1000] loss0.011-|Sample:0.10|
# EPOCH[372/1000] loss0.011-|Sample:0.10|
# EPOCH[373/1000] loss0.011-|Sample:0.10|
# EPOCH[374/1000] loss0.011-|Sample:0.10|
# EPOCH[375/1000] loss0.011-|Sample:0.10|
# EPOCH[376/1000] loss0.011-|Sample:0.10|
# EPOCH[377/1000] loss0.011-|Sample:0.10|
# EPOCH[378/1000] loss0.011-|Sample:0.10|
# EPOCH[379/1000] loss0.011-|Sample:0.10|
# EPOCH[380/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05522138]), 'recall': array([0.18044839]), 'ndcg': array([0.15391729])}
# EPOCH[381/1000] loss0.011-|Sample:0.09|
# EPOCH[382/1000] loss0.011-|Sample:0.10|
# EPOCH[383/1000] loss0.011-|Sample:0.10|
# EPOCH[384/1000] loss0.011-|Sample:0.10|
# EPOCH[385/1000] loss0.011-|Sample:0.10|
# EPOCH[386/1000] loss0.011-|Sample:0.10|
# EPOCH[387/1000] loss0.011-|Sample:0.10|
# EPOCH[388/1000] loss0.011-|Sample:0.10|
# EPOCH[389/1000] loss0.011-|Sample:0.10|
# EPOCH[390/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05525487]), 'recall': array([0.1806298]), 'ndcg': array([0.15420522])}
# EPOCH[391/1000] loss0.011-|Sample:0.12|
# EPOCH[392/1000] loss0.011-|Sample:0.10|
# EPOCH[393/1000] loss0.011-|Sample:0.10|
# EPOCH[394/1000] loss0.011-|Sample:0.10|
# EPOCH[395/1000] loss0.011-|Sample:0.10|
# EPOCH[396/1000] loss0.011-|Sample:0.10|
# EPOCH[397/1000] loss0.011-|Sample:0.10|
# EPOCH[398/1000] loss0.011-|Sample:0.10|
# EPOCH[399/1000] loss0.011-|Sample:0.10|
# EPOCH[400/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05524148]), 'recall': array([0.18064533]), 'ndcg': array([0.15408465])}
# EPOCH[401/1000] loss0.011-|Sample:0.10|
# EPOCH[402/1000] loss0.011-|Sample:0.10|
# EPOCH[403/1000] loss0.011-|Sample:0.10|
# EPOCH[404/1000] loss0.011-|Sample:0.10|
# EPOCH[405/1000] loss0.011-|Sample:0.10|
# EPOCH[406/1000] loss0.011-|Sample:0.10|
# EPOCH[407/1000] loss0.011-|Sample:0.10|
# EPOCH[408/1000] loss0.011-|Sample:0.10|
# EPOCH[409/1000] loss0.011-|Sample:0.10|
# EPOCH[410/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05541228]), 'recall': array([0.18096806]), 'ndcg': array([0.15427429])}
# EPOCH[411/1000] loss0.011-|Sample:0.09|
# EPOCH[412/1000] loss0.011-|Sample:0.10|
# EPOCH[413/1000] loss0.011-|Sample:0.10|
# EPOCH[414/1000] loss0.011-|Sample:0.10|
# EPOCH[415/1000] loss0.011-|Sample:0.10|
# EPOCH[416/1000] loss0.011-|Sample:0.10|
# EPOCH[417/1000] loss0.011-|Sample:0.10|
# EPOCH[418/1000] loss0.011-|Sample:0.10|
# EPOCH[419/1000] loss0.011-|Sample:0.10|
# EPOCH[420/1000] loss0.011-|Sample:0.09|
# [TEST]
# {'precision': array([0.05549099]), 'recall': array([0.18115476]), 'ndcg': array([0.15439541])}
# EPOCH[421/1000] loss0.011-|Sample:0.09|
# EPOCH[422/1000] loss0.011-|Sample:0.10|
# EPOCH[423/1000] loss0.011-|Sample:0.10|
# EPOCH[424/1000] loss0.011-|Sample:0.10|
# EPOCH[425/1000] loss0.011-|Sample:0.10|
# EPOCH[426/1000] loss0.011-|Sample:0.10|
# EPOCH[427/1000] loss0.011-|Sample:0.10|
# EPOCH[428/1000] loss0.011-|Sample:0.10|
# EPOCH[429/1000] loss0.011-|Sample:0.10|
# EPOCH[430/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05534865]), 'recall': array([0.18062069]), 'ndcg': array([0.15431581])}
# EPOCH[431/1000] loss0.011-|Sample:0.10|
# EPOCH[432/1000] loss0.011-|Sample:0.10|
# EPOCH[433/1000] loss0.011-|Sample:0.10|
# EPOCH[434/1000] loss0.011-|Sample:0.10|
# EPOCH[435/1000] loss0.011-|Sample:0.10|
# EPOCH[436/1000] loss0.011-|Sample:0.11|
# EPOCH[437/1000] loss0.011-|Sample:0.10|
# EPOCH[438/1000] loss0.011-|Sample:0.09|
# EPOCH[439/1000] loss0.011-|Sample:0.10|
# EPOCH[440/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05539219]), 'recall': array([0.18072935]), 'ndcg': array([0.15407258])}
# EPOCH[441/1000] loss0.011-|Sample:0.10|
# EPOCH[442/1000] loss0.011-|Sample:0.10|
# EPOCH[443/1000] loss0.011-|Sample:0.10|
# EPOCH[444/1000] loss0.011-|Sample:0.10|
# EPOCH[445/1000] loss0.011-|Sample:0.10|
# EPOCH[446/1000] loss0.011-|Sample:0.10|
# EPOCH[447/1000] loss0.011-|Sample:0.10|
# EPOCH[448/1000] loss0.011-|Sample:0.10|
# EPOCH[449/1000] loss0.011-|Sample:0.10|
# EPOCH[450/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.0554508]), 'recall': array([0.18081999]), 'ndcg': array([0.15403541])}
# EPOCH[451/1000] loss0.011-|Sample:0.09|
# EPOCH[452/1000] loss0.011-|Sample:0.10|
# EPOCH[453/1000] loss0.011-|Sample:0.10|
# EPOCH[454/1000] loss0.011-|Sample:0.10|
# EPOCH[455/1000] loss0.011-|Sample:0.10|
# EPOCH[456/1000] loss0.011-|Sample:0.10|
# EPOCH[457/1000] loss0.011-|Sample:0.10|
# EPOCH[458/1000] loss0.011-|Sample:0.10|
# EPOCH[459/1000] loss0.011-|Sample:0.09|
# EPOCH[460/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05538047]), 'recall': array([0.18055986]), 'ndcg': array([0.15392902])}
# EPOCH[461/1000] loss0.011-|Sample:0.10|
# EPOCH[462/1000] loss0.011-|Sample:0.09|
# EPOCH[463/1000] loss0.011-|Sample:0.09|
# EPOCH[464/1000] loss0.011-|Sample:0.10|
# EPOCH[465/1000] loss0.011-|Sample:0.10|
# EPOCH[466/1000] loss0.011-|Sample:0.10|
# EPOCH[467/1000] loss0.011-|Sample:0.10|
# EPOCH[468/1000] loss0.011-|Sample:0.10|
# EPOCH[469/1000] loss0.011-|Sample:0.10|
# EPOCH[470/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.0554642]), 'recall': array([0.18083127]), 'ndcg': array([0.15428643])}
# EPOCH[471/1000] loss0.011-|Sample:0.11|
# EPOCH[472/1000] loss0.011-|Sample:0.11|
# EPOCH[473/1000] loss0.011-|Sample:0.10|
# EPOCH[474/1000] loss0.011-|Sample:0.10|
# EPOCH[475/1000] loss0.011-|Sample:0.10|
# EPOCH[476/1000] loss0.010-|Sample:0.10|
# EPOCH[477/1000] loss0.011-|Sample:0.10|
# EPOCH[478/1000] loss0.011-|Sample:0.10|
# EPOCH[479/1000] loss0.011-|Sample:0.10|
# EPOCH[480/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05556467]), 'recall': array([0.18122695]), 'ndcg': array([0.15440688])}
# EPOCH[481/1000] loss0.011-|Sample:0.10|
# EPOCH[482/1000] loss0.010-|Sample:0.10|
# EPOCH[483/1000] loss0.011-|Sample:0.10|
# EPOCH[484/1000] loss0.011-|Sample:0.10|
# EPOCH[485/1000] loss0.010-|Sample:0.11|
# EPOCH[486/1000] loss0.011-|Sample:0.11|
# EPOCH[487/1000] loss0.011-|Sample:0.10|
# EPOCH[488/1000] loss0.011-|Sample:0.11|
# EPOCH[489/1000] loss0.011-|Sample:0.10|
# EPOCH[490/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05567017]), 'recall': array([0.18132792]), 'ndcg': array([0.15463859])}
# EPOCH[491/1000] loss0.011-|Sample:0.10|
# EPOCH[492/1000] loss0.011-|Sample:0.10|
# EPOCH[493/1000] loss0.011-|Sample:0.10|
# EPOCH[494/1000] loss0.011-|Sample:0.10|
# EPOCH[495/1000] loss0.011-|Sample:0.10|
# EPOCH[496/1000] loss0.011-|Sample:0.10|
# EPOCH[497/1000] loss0.011-|Sample:0.10|
# EPOCH[498/1000] loss0.010-|Sample:0.10|
# EPOCH[499/1000] loss0.011-|Sample:0.10|
# EPOCH[500/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05576562]), 'recall': array([0.18163998]), 'ndcg': array([0.15486876])}
# EPOCH[501/1000] loss0.011-|Sample:0.12|
# EPOCH[502/1000] loss0.011-|Sample:0.10|
# EPOCH[503/1000] loss0.011-|Sample:0.10|
# EPOCH[504/1000] loss0.011-|Sample:0.10|
# EPOCH[505/1000] loss0.010-|Sample:0.10|
# EPOCH[506/1000] loss0.011-|Sample:0.11|
# EPOCH[507/1000] loss0.010-|Sample:0.10|
# EPOCH[508/1000] loss0.011-|Sample:0.10|
# EPOCH[509/1000] loss0.011-|Sample:0.10|
# EPOCH[510/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05584768]), 'recall': array([0.18163563]), 'ndcg': array([0.15498274])}
# EPOCH[511/1000] loss0.011-|Sample:0.10|
# EPOCH[512/1000] loss0.011-|Sample:0.11|
# EPOCH[513/1000] loss0.010-|Sample:0.10|
# EPOCH[514/1000] loss0.010-|Sample:0.10|
# EPOCH[515/1000] loss0.010-|Sample:0.10|
# EPOCH[516/1000] loss0.010-|Sample:0.10|
# EPOCH[517/1000] loss0.011-|Sample:0.10|
# EPOCH[518/1000] loss0.010-|Sample:0.10|
# EPOCH[519/1000] loss0.011-|Sample:0.10|
# EPOCH[520/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05596323]), 'recall': array([0.18232901]), 'ndcg': array([0.15503316])}
# EPOCH[521/1000] loss0.011-|Sample:0.09|
# EPOCH[522/1000] loss0.011-|Sample:0.10|
# EPOCH[523/1000] loss0.010-|Sample:0.10|
# EPOCH[524/1000] loss0.011-|Sample:0.10|
# EPOCH[525/1000] loss0.011-|Sample:0.10|
# EPOCH[526/1000] loss0.011-|Sample:0.10|
# EPOCH[527/1000] loss0.011-|Sample:0.10|
# EPOCH[528/1000] loss0.011-|Sample:0.10|
# EPOCH[529/1000] loss0.010-|Sample:0.10|
# EPOCH[530/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05587615]), 'recall': array([0.18214931]), 'ndcg': array([0.15492573])}
# EPOCH[531/1000] loss0.010-|Sample:0.09|
# EPOCH[532/1000] loss0.010-|Sample:0.10|
# EPOCH[533/1000] loss0.010-|Sample:0.10|
# EPOCH[534/1000] loss0.010-|Sample:0.10|
# EPOCH[535/1000] loss0.010-|Sample:0.10|
# EPOCH[536/1000] loss0.010-|Sample:0.11|
# EPOCH[537/1000] loss0.010-|Sample:0.10|
# EPOCH[538/1000] loss0.010-|Sample:0.10|
# EPOCH[539/1000] loss0.010-|Sample:0.10|
# EPOCH[540/1000] loss0.011-|Sample:0.10|
# [TEST]
# {'precision': array([0.05586108]), 'recall': array([0.18217797]), 'ndcg': array([0.15496356])}
# EPOCH[541/1000] loss0.010-|Sample:0.10|
# EPOCH[542/1000] loss0.011-|Sample:0.10|
# EPOCH[543/1000] loss0.011-|Sample:0.10|
# EPOCH[544/1000] loss0.010-|Sample:0.10|
# EPOCH[545/1000] loss0.010-|Sample:0.10|
# EPOCH[546/1000] loss0.011-|Sample:0.10|
# EPOCH[547/1000] loss0.010-|Sample:0.10|
# EPOCH[548/1000] loss0.010-|Sample:0.10|
# EPOCH[549/1000] loss0.010-|Sample:0.10|
# EPOCH[550/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05590294]), 'recall': array([0.18229196]), 'ndcg': array([0.1550832])}
# EPOCH[551/1000] loss0.010-|Sample:0.10|
# EPOCH[552/1000] loss0.010-|Sample:0.10|
# EPOCH[553/1000] loss0.010-|Sample:0.10|
# EPOCH[554/1000] loss0.010-|Sample:0.10|
# EPOCH[555/1000] loss0.010-|Sample:0.10|
# EPOCH[556/1000] loss0.010-|Sample:0.11|
# EPOCH[557/1000] loss0.010-|Sample:0.10|
# EPOCH[558/1000] loss0.010-|Sample:0.10|
# EPOCH[559/1000] loss0.010-|Sample:0.10|
# EPOCH[560/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05611729]), 'recall': array([0.18298593]), 'ndcg': array([0.15559013])}
# EPOCH[561/1000] loss0.010-|Sample:0.10|
# EPOCH[562/1000] loss0.010-|Sample:0.10|
# EPOCH[563/1000] loss0.010-|Sample:0.10|
# EPOCH[564/1000] loss0.010-|Sample:0.11|
# EPOCH[565/1000] loss0.010-|Sample:0.10|
# EPOCH[566/1000] loss0.010-|Sample:0.10|
# EPOCH[567/1000] loss0.010-|Sample:0.10|
# EPOCH[568/1000] loss0.010-|Sample:0.10|
# EPOCH[569/1000] loss0.010-|Sample:0.10|
# EPOCH[570/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05605533]), 'recall': array([0.18263282]), 'ndcg': array([0.15523885])}
# EPOCH[571/1000] loss0.010-|Sample:0.10|
# EPOCH[572/1000] loss0.010-|Sample:0.10|
# EPOCH[573/1000] loss0.010-|Sample:0.10|
# EPOCH[574/1000] loss0.010-|Sample:0.10|
# EPOCH[575/1000] loss0.010-|Sample:0.10|
# EPOCH[576/1000] loss0.010-|Sample:0.10|
# EPOCH[577/1000] loss0.010-|Sample:0.11|
# EPOCH[578/1000] loss0.010-|Sample:0.10|
# EPOCH[579/1000] loss0.010-|Sample:0.10|
# EPOCH[580/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05607877]), 'recall': array([0.18274292]), 'ndcg': array([0.15525462])}
# EPOCH[581/1000] loss0.010-|Sample:0.10|
# EPOCH[582/1000] loss0.010-|Sample:0.10|
# EPOCH[583/1000] loss0.010-|Sample:0.10|
# EPOCH[584/1000] loss0.010-|Sample:0.10|
# EPOCH[585/1000] loss0.010-|Sample:0.10|
# EPOCH[586/1000] loss0.010-|Sample:0.10|
# EPOCH[587/1000] loss0.010-|Sample:0.10|
# EPOCH[588/1000] loss0.010-|Sample:0.10|
# EPOCH[589/1000] loss0.010-|Sample:0.10|
# EPOCH[590/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05583261]), 'recall': array([0.18169327]), 'ndcg': array([0.15496242])}
# EPOCH[591/1000] loss0.010-|Sample:0.09|
# EPOCH[592/1000] loss0.010-|Sample:0.10|
# EPOCH[593/1000] loss0.010-|Sample:0.10|
# EPOCH[594/1000] loss0.010-|Sample:0.10|
# EPOCH[595/1000] loss0.010-|Sample:0.10|
# EPOCH[596/1000] loss0.010-|Sample:0.10|
# EPOCH[597/1000] loss0.010-|Sample:0.10|
# EPOCH[598/1000] loss0.010-|Sample:0.10|
# EPOCH[599/1000] loss0.010-|Sample:0.10|
# EPOCH[600/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05594481]), 'recall': array([0.18228648]), 'ndcg': array([0.15511292])}
# EPOCH[601/1000] loss0.010-|Sample:0.09|
# EPOCH[602/1000] loss0.010-|Sample:0.10|
# EPOCH[603/1000] loss0.010-|Sample:0.10|
# EPOCH[604/1000] loss0.010-|Sample:0.10|
# EPOCH[605/1000] loss0.010-|Sample:0.10|
# EPOCH[606/1000] loss0.010-|Sample:0.10|
# EPOCH[607/1000] loss0.010-|Sample:0.11|
# EPOCH[608/1000] loss0.010-|Sample:0.10|
# EPOCH[609/1000] loss0.010-|Sample:0.10|
# EPOCH[610/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05593978]), 'recall': array([0.18198589]), 'ndcg': array([0.15477574])}
# EPOCH[611/1000] loss0.010-|Sample:0.09|
# EPOCH[612/1000] loss0.010-|Sample:0.10|
# EPOCH[613/1000] loss0.010-|Sample:0.10|
# EPOCH[614/1000] loss0.010-|Sample:0.10|
# EPOCH[615/1000] loss0.010-|Sample:0.10|
# EPOCH[616/1000] loss0.010-|Sample:0.10|
# EPOCH[617/1000] loss0.010-|Sample:0.10|
# EPOCH[618/1000] loss0.010-|Sample:0.10|
# EPOCH[619/1000] loss0.010-|Sample:0.10|
# EPOCH[620/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.055985]), 'recall': array([0.18210327]), 'ndcg': array([0.15523626])}
# EPOCH[621/1000] loss0.010-|Sample:0.10|
# EPOCH[622/1000] loss0.010-|Sample:0.10|
# EPOCH[623/1000] loss0.010-|Sample:0.10|
# EPOCH[624/1000] loss0.010-|Sample:0.10|
# EPOCH[625/1000] loss0.010-|Sample:0.10|
# EPOCH[626/1000] loss0.010-|Sample:0.10|
# EPOCH[627/1000] loss0.010-|Sample:0.10|
# EPOCH[628/1000] loss0.010-|Sample:0.10|
# EPOCH[629/1000] loss0.010-|Sample:0.10|
# EPOCH[630/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05613069]), 'recall': array([0.18262002]), 'ndcg': array([0.155479])}
# EPOCH[631/1000] loss0.010-|Sample:0.10|
# EPOCH[632/1000] loss0.010-|Sample:0.10|
# EPOCH[633/1000] loss0.010-|Sample:0.11|
# EPOCH[634/1000] loss0.010-|Sample:0.10|
# EPOCH[635/1000] loss0.010-|Sample:0.10|
# EPOCH[636/1000] loss0.010-|Sample:0.10|
# EPOCH[637/1000] loss0.010-|Sample:0.10|
# EPOCH[638/1000] loss0.010-|Sample:0.10|
# EPOCH[639/1000] loss0.010-|Sample:0.10|
# EPOCH[640/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05620437]), 'recall': array([0.18303674]), 'ndcg': array([0.15563642])}
# EPOCH[641/1000] loss0.010-|Sample:0.10|
# EPOCH[642/1000] loss0.010-|Sample:0.10|
# EPOCH[643/1000] loss0.010-|Sample:0.10|
# EPOCH[644/1000] loss0.010-|Sample:0.10|
# EPOCH[645/1000] loss0.010-|Sample:0.10|
# EPOCH[646/1000] loss0.010-|Sample:0.10|
# EPOCH[647/1000] loss0.010-|Sample:0.10|
# EPOCH[648/1000] loss0.010-|Sample:0.10|
# EPOCH[649/1000] loss0.010-|Sample:0.10|
# EPOCH[650/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05611729]), 'recall': array([0.18293093]), 'ndcg': array([0.15542075])}
# EPOCH[651/1000] loss0.010-|Sample:0.10|
# EPOCH[652/1000] loss0.010-|Sample:0.10|
# EPOCH[653/1000] loss0.010-|Sample:0.10|
# EPOCH[654/1000] loss0.010-|Sample:0.10|
# EPOCH[655/1000] loss0.010-|Sample:0.10|
# EPOCH[656/1000] loss0.010-|Sample:0.10|
# EPOCH[657/1000] loss0.010-|Sample:0.10|
# EPOCH[658/1000] loss0.010-|Sample:0.10|
# EPOCH[659/1000] loss0.010-|Sample:0.10|
# EPOCH[660/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05615413]), 'recall': array([0.18296678]), 'ndcg': array([0.15566998])}
# EPOCH[661/1000] loss0.010-|Sample:0.10|
# EPOCH[662/1000] loss0.010-|Sample:0.10|
# EPOCH[663/1000] loss0.010-|Sample:0.10|
# EPOCH[664/1000] loss0.010-|Sample:0.10|
# EPOCH[665/1000] loss0.010-|Sample:0.10|
# EPOCH[666/1000] loss0.010-|Sample:0.10|
# EPOCH[667/1000] loss0.010-|Sample:0.10|
# EPOCH[668/1000] loss0.010-|Sample:0.11|
# EPOCH[669/1000] loss0.010-|Sample:0.10|
# EPOCH[670/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05593978]), 'recall': array([0.18237178]), 'ndcg': array([0.15515617])}
# EPOCH[671/1000] loss0.010-|Sample:0.09|
# EPOCH[672/1000] loss0.010-|Sample:0.10|
# EPOCH[673/1000] loss0.010-|Sample:0.10|
# EPOCH[674/1000] loss0.010-|Sample:0.10|
# EPOCH[675/1000] loss0.010-|Sample:0.10|
# EPOCH[676/1000] loss0.010-|Sample:0.10|
# EPOCH[677/1000] loss0.010-|Sample:0.10|
# EPOCH[678/1000] loss0.010-|Sample:0.10|
# EPOCH[679/1000] loss0.010-|Sample:0.10|
# EPOCH[680/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.0560637]), 'recall': array([0.18237772]), 'ndcg': array([0.15523397])}
# EPOCH[681/1000] loss0.010-|Sample:0.10|
# EPOCH[682/1000] loss0.010-|Sample:0.10|
# EPOCH[683/1000] loss0.010-|Sample:0.10|
# EPOCH[684/1000] loss0.010-|Sample:0.10|
# EPOCH[685/1000] loss0.010-|Sample:0.10|
# EPOCH[686/1000] loss0.010-|Sample:0.10|
# EPOCH[687/1000] loss0.010-|Sample:0.10|
# EPOCH[688/1000] loss0.010-|Sample:0.10|
# EPOCH[689/1000] loss0.010-|Sample:0.10|
# EPOCH[690/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05622279]), 'recall': array([0.18290596]), 'ndcg': array([0.15553529])}
# EPOCH[691/1000] loss0.010-|Sample:0.10|
# EPOCH[692/1000] loss0.010-|Sample:0.10|
# EPOCH[693/1000] loss0.010-|Sample:0.10|
# EPOCH[694/1000] loss0.010-|Sample:0.10|
# EPOCH[695/1000] loss0.010-|Sample:0.10|
# EPOCH[696/1000] loss0.010-|Sample:0.10|
# EPOCH[697/1000] loss0.010-|Sample:0.10|
# EPOCH[698/1000] loss0.010-|Sample:0.09|
# EPOCH[699/1000] loss0.010-|Sample:0.10|
# EPOCH[700/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05616083]), 'recall': array([0.18285523]), 'ndcg': array([0.15550562])}
# EPOCH[701/1000] loss0.010-|Sample:0.09|
# EPOCH[702/1000] loss0.010-|Sample:0.10|
# EPOCH[703/1000] loss0.010-|Sample:0.10|
# EPOCH[704/1000] loss0.010-|Sample:0.10|
# EPOCH[705/1000] loss0.010-|Sample:0.10|
# EPOCH[706/1000] loss0.010-|Sample:0.10|
# EPOCH[707/1000] loss0.010-|Sample:0.10|
# EPOCH[708/1000] loss0.010-|Sample:0.10|
# EPOCH[709/1000] loss0.010-|Sample:0.10|
# EPOCH[710/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05607542]), 'recall': array([0.18279439]), 'ndcg': array([0.1554812])}
# EPOCH[711/1000] loss0.010-|Sample:0.10|
# EPOCH[712/1000] loss0.010-|Sample:0.10|
# EPOCH[713/1000] loss0.010-|Sample:0.10|
# EPOCH[714/1000] loss0.010-|Sample:0.10|
# EPOCH[715/1000] loss0.010-|Sample:0.10|
# EPOCH[716/1000] loss0.010-|Sample:0.10|
# EPOCH[717/1000] loss0.010-|Sample:0.10|
# EPOCH[718/1000] loss0.010-|Sample:0.10|
# EPOCH[719/1000] loss0.010-|Sample:0.10|
# EPOCH[720/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05599337]), 'recall': array([0.18239036]), 'ndcg': array([0.15533505])}
# EPOCH[721/1000] loss0.010-|Sample:0.10|
# EPOCH[722/1000] loss0.010-|Sample:0.10|
# EPOCH[723/1000] loss0.010-|Sample:0.10|
# EPOCH[724/1000] loss0.010-|Sample:0.10|
# EPOCH[725/1000] loss0.010-|Sample:0.10|
# EPOCH[726/1000] loss0.010-|Sample:0.10|
# EPOCH[727/1000] loss0.010-|Sample:0.10|
# EPOCH[728/1000] loss0.010-|Sample:0.10|
# EPOCH[729/1000] loss0.010-|Sample:0.10|
# EPOCH[730/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05608882]), 'recall': array([0.1829867]), 'ndcg': array([0.15551832])}
# EPOCH[731/1000] loss0.010-|Sample:0.10|
# EPOCH[732/1000] loss0.010-|Sample:0.09|
# EPOCH[733/1000] loss0.010-|Sample:0.10|
# EPOCH[734/1000] loss0.010-|Sample:0.10|
# EPOCH[735/1000] loss0.010-|Sample:0.09|
# EPOCH[736/1000] loss0.010-|Sample:0.10|
# EPOCH[737/1000] loss0.010-|Sample:0.10|
# EPOCH[738/1000] loss0.010-|Sample:0.11|
# EPOCH[739/1000] loss0.010-|Sample:0.10|
# EPOCH[740/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.0561558]), 'recall': array([0.18335365]), 'ndcg': array([0.15573732])}
# EPOCH[741/1000] loss0.010-|Sample:0.09|
# EPOCH[742/1000] loss0.010-|Sample:0.10|
# EPOCH[743/1000] loss0.010-|Sample:0.10|
# EPOCH[744/1000] loss0.010-|Sample:0.10|
# EPOCH[745/1000] loss0.010-|Sample:0.10|
# EPOCH[746/1000] loss0.010-|Sample:0.10|
# EPOCH[747/1000] loss0.010-|Sample:0.10|
# EPOCH[748/1000] loss0.010-|Sample:0.10|
# EPOCH[749/1000] loss0.010-|Sample:0.10|
# EPOCH[750/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05620269]), 'recall': array([0.18283897]), 'ndcg': array([0.15566348])}
# EPOCH[751/1000] loss0.010-|Sample:0.10|
# EPOCH[752/1000] loss0.010-|Sample:0.10|
# EPOCH[753/1000] loss0.010-|Sample:0.10|
# EPOCH[754/1000] loss0.010-|Sample:0.10|
# EPOCH[755/1000] loss0.010-|Sample:0.10|
# EPOCH[756/1000] loss0.010-|Sample:0.10|
# EPOCH[757/1000] loss0.010-|Sample:0.10|
# EPOCH[758/1000] loss0.010-|Sample:0.10|
# EPOCH[759/1000] loss0.010-|Sample:0.09|
# EPOCH[760/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05623284]), 'recall': array([0.18315176]), 'ndcg': array([0.15548629])}
# EPOCH[761/1000] loss0.010-|Sample:0.09|
# EPOCH[762/1000] loss0.010-|Sample:0.10|
# EPOCH[763/1000] loss0.010-|Sample:0.10|
# EPOCH[764/1000] loss0.010-|Sample:0.10|
# EPOCH[765/1000] loss0.010-|Sample:0.10|
# EPOCH[766/1000] loss0.010-|Sample:0.10|
# EPOCH[767/1000] loss0.010-|Sample:0.10|
# EPOCH[768/1000] loss0.010-|Sample:0.10|
# EPOCH[769/1000] loss0.010-|Sample:0.10|
# EPOCH[770/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.056268]), 'recall': array([0.18320063]), 'ndcg': array([0.15578907])}
# EPOCH[771/1000] loss0.010-|Sample:0.10|
# EPOCH[772/1000] loss0.010-|Sample:0.10|
# EPOCH[773/1000] loss0.010-|Sample:0.10|
# EPOCH[774/1000] loss0.010-|Sample:0.10|
# EPOCH[775/1000] loss0.010-|Sample:0.10|
# EPOCH[776/1000] loss0.010-|Sample:0.10|
# EPOCH[777/1000] loss0.010-|Sample:0.10|
# EPOCH[778/1000] loss0.010-|Sample:0.10|
# EPOCH[779/1000] loss0.010-|Sample:0.10|
# EPOCH[780/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05605533]), 'recall': array([0.18239539]), 'ndcg': array([0.15566809])}
# EPOCH[781/1000] loss0.010-|Sample:0.10|
# EPOCH[782/1000] loss0.010-|Sample:0.10|
# EPOCH[783/1000] loss0.010-|Sample:0.09|
# EPOCH[784/1000] loss0.010-|Sample:0.09|
# EPOCH[785/1000] loss0.010-|Sample:0.10|
# EPOCH[786/1000] loss0.010-|Sample:0.10|
# EPOCH[787/1000] loss0.010-|Sample:0.10|
# EPOCH[788/1000] loss0.010-|Sample:0.10|
# EPOCH[789/1000] loss0.010-|Sample:0.10|
# EPOCH[790/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05599839]), 'recall': array([0.18257914]), 'ndcg': array([0.15564538])}
# EPOCH[791/1000] loss0.010-|Sample:0.10|
# EPOCH[792/1000] loss0.010-|Sample:0.10|
# EPOCH[793/1000] loss0.010-|Sample:0.10|
# EPOCH[794/1000] loss0.010-|Sample:0.10|
# EPOCH[795/1000] loss0.010-|Sample:0.10|
# EPOCH[796/1000] loss0.010-|Sample:0.10|
# EPOCH[797/1000] loss0.010-|Sample:0.10|
# EPOCH[798/1000] loss0.010-|Sample:0.09|
# EPOCH[799/1000] loss0.010-|Sample:0.10|
# EPOCH[800/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05616083]), 'recall': array([0.18314083]), 'ndcg': array([0.15589221])}
# EPOCH[801/1000] loss0.010-|Sample:0.11|
# EPOCH[802/1000] loss0.010-|Sample:0.10|
# EPOCH[803/1000] loss0.010-|Sample:0.10|
# EPOCH[804/1000] loss0.010-|Sample:0.10|
# EPOCH[805/1000] loss0.010-|Sample:0.10|
# EPOCH[806/1000] loss0.010-|Sample:0.10|
# EPOCH[807/1000] loss0.010-|Sample:0.09|
# EPOCH[808/1000] loss0.010-|Sample:0.10|
# EPOCH[809/1000] loss0.010-|Sample:0.10|
# EPOCH[810/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05621944]), 'recall': array([0.18331955]), 'ndcg': array([0.15593047])}
# EPOCH[811/1000] loss0.010-|Sample:0.10|
# EPOCH[812/1000] loss0.010-|Sample:0.10|
# EPOCH[813/1000] loss0.010-|Sample:0.10|
# EPOCH[814/1000] loss0.010-|Sample:0.10|
# EPOCH[815/1000] loss0.010-|Sample:0.10|
# EPOCH[816/1000] loss0.010-|Sample:0.10|
# EPOCH[817/1000] loss0.010-|Sample:0.10|
# EPOCH[818/1000] loss0.010-|Sample:0.10|
# EPOCH[819/1000] loss0.010-|Sample:0.10|
# EPOCH[820/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05623451]), 'recall': array([0.18354411]), 'ndcg': array([0.15599679])}
# EPOCH[821/1000] loss0.010-|Sample:0.10|
# EPOCH[822/1000] loss0.010-|Sample:0.10|
# EPOCH[823/1000] loss0.010-|Sample:0.10|
# EPOCH[824/1000] loss0.010-|Sample:0.10|
# EPOCH[825/1000] loss0.010-|Sample:0.10|
# EPOCH[826/1000] loss0.010-|Sample:0.10|
# EPOCH[827/1000] loss0.010-|Sample:0.10|
# EPOCH[828/1000] loss0.010-|Sample:0.10|
# EPOCH[829/1000] loss0.010-|Sample:0.10|
# EPOCH[830/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05623618]), 'recall': array([0.18337041]), 'ndcg': array([0.15599156])}
# EPOCH[831/1000] loss0.010-|Sample:0.10|
# EPOCH[832/1000] loss0.010-|Sample:0.10|
# EPOCH[833/1000] loss0.010-|Sample:0.10|
# EPOCH[834/1000] loss0.010-|Sample:0.10|
# EPOCH[835/1000] loss0.010-|Sample:0.10|
# EPOCH[836/1000] loss0.010-|Sample:0.10|
# EPOCH[837/1000] loss0.010-|Sample:0.10|
# EPOCH[838/1000] loss0.010-|Sample:0.10|
# EPOCH[839/1000] loss0.010-|Sample:0.10|
# EPOCH[840/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05618092]), 'recall': array([0.18343345]), 'ndcg': array([0.15620723])}
# EPOCH[841/1000] loss0.010-|Sample:0.10|
# EPOCH[842/1000] loss0.010-|Sample:0.10|
# EPOCH[843/1000] loss0.010-|Sample:0.10|
# EPOCH[844/1000] loss0.010-|Sample:0.10|
# EPOCH[845/1000] loss0.010-|Sample:0.10|
# EPOCH[846/1000] loss0.010-|Sample:0.10|
# EPOCH[847/1000] loss0.010-|Sample:0.10|
# EPOCH[848/1000] loss0.010-|Sample:0.10|
# EPOCH[849/1000] loss0.010-|Sample:0.10|
# EPOCH[850/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05622781]), 'recall': array([0.18315846]), 'ndcg': array([0.1558651])}
# EPOCH[851/1000] loss0.010-|Sample:0.10|
# EPOCH[852/1000] loss0.010-|Sample:0.10|
# EPOCH[853/1000] loss0.010-|Sample:0.10|
# EPOCH[854/1000] loss0.010-|Sample:0.10|
# EPOCH[855/1000] loss0.010-|Sample:0.10|
# EPOCH[856/1000] loss0.010-|Sample:0.10|
# EPOCH[857/1000] loss0.010-|Sample:0.10|
# EPOCH[858/1000] loss0.010-|Sample:0.10|
# EPOCH[859/1000] loss0.010-|Sample:0.10|
# EPOCH[860/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05623116]), 'recall': array([0.18286617]), 'ndcg': array([0.15573349])}
# EPOCH[861/1000] loss0.010-|Sample:0.10|
# EPOCH[862/1000] loss0.010-|Sample:0.10|
# EPOCH[863/1000] loss0.010-|Sample:0.10|
# EPOCH[864/1000] loss0.010-|Sample:0.10|
# EPOCH[865/1000] loss0.010-|Sample:0.10|
# EPOCH[866/1000] loss0.010-|Sample:0.10|
# EPOCH[867/1000] loss0.010-|Sample:0.10|
# EPOCH[868/1000] loss0.010-|Sample:0.10|
# EPOCH[869/1000] loss0.010-|Sample:0.10|
# EPOCH[870/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05626298]), 'recall': array([0.18323179]), 'ndcg': array([0.15589286])}
# EPOCH[871/1000] loss0.010-|Sample:0.10|
# EPOCH[872/1000] loss0.010-|Sample:0.10|
# EPOCH[873/1000] loss0.010-|Sample:0.10|
# EPOCH[874/1000] loss0.010-|Sample:0.10|
# EPOCH[875/1000] loss0.010-|Sample:0.10|
# EPOCH[876/1000] loss0.010-|Sample:0.10|
# EPOCH[877/1000] loss0.010-|Sample:0.10|
# EPOCH[878/1000] loss0.010-|Sample:0.10|
# EPOCH[879/1000] loss0.010-|Sample:0.10|
# EPOCH[880/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05615748]), 'recall': array([0.1830054]), 'ndcg': array([0.15578555])}
# EPOCH[881/1000] loss0.010-|Sample:0.10|
# EPOCH[882/1000] loss0.010-|Sample:0.10|
# EPOCH[883/1000] loss0.010-|Sample:0.10|
# EPOCH[884/1000] loss0.010-|Sample:0.10|
# EPOCH[885/1000] loss0.010-|Sample:0.10|
# EPOCH[886/1000] loss0.010-|Sample:0.10|
# EPOCH[887/1000] loss0.010-|Sample:0.10|
# EPOCH[888/1000] loss0.010-|Sample:0.10|
# EPOCH[889/1000] loss0.010-|Sample:0.10|
# EPOCH[890/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05614241]), 'recall': array([0.18298271]), 'ndcg': array([0.15608217])}
# EPOCH[891/1000] loss0.010-|Sample:0.09|
# EPOCH[892/1000] loss0.010-|Sample:0.10|
# EPOCH[893/1000] loss0.010-|Sample:0.09|
# EPOCH[894/1000] loss0.010-|Sample:0.10|
# EPOCH[895/1000] loss0.010-|Sample:0.11|
# EPOCH[896/1000] loss0.010-|Sample:0.10|
# EPOCH[897/1000] loss0.010-|Sample:0.10|
# EPOCH[898/1000] loss0.010-|Sample:0.10|
# EPOCH[899/1000] loss0.010-|Sample:0.10|
# EPOCH[900/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05631991]), 'recall': array([0.18329616]), 'ndcg': array([0.15593518])}
# EPOCH[901/1000] loss0.010-|Sample:0.10|
# EPOCH[902/1000] loss0.010-|Sample:0.10|
# EPOCH[903/1000] loss0.010-|Sample:0.10|
# EPOCH[904/1000] loss0.010-|Sample:0.10|
# EPOCH[905/1000] loss0.010-|Sample:0.10|
# EPOCH[906/1000] loss0.010-|Sample:0.10|
# EPOCH[907/1000] loss0.010-|Sample:0.10|
# EPOCH[908/1000] loss0.010-|Sample:0.10|
# EPOCH[909/1000] loss0.010-|Sample:0.10|
# EPOCH[910/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.0561625]), 'recall': array([0.18289415]), 'ndcg': array([0.15566068])}
# EPOCH[911/1000] loss0.010-|Sample:0.10|
# EPOCH[912/1000] loss0.010-|Sample:0.10|
# EPOCH[913/1000] loss0.010-|Sample:0.10|
# EPOCH[914/1000] loss0.010-|Sample:0.10|
# EPOCH[915/1000] loss0.010-|Sample:0.10|
# EPOCH[916/1000] loss0.010-|Sample:0.09|
# EPOCH[917/1000] loss0.010-|Sample:0.10|
# EPOCH[918/1000] loss0.010-|Sample:0.10|
# EPOCH[919/1000] loss0.010-|Sample:0.10|
# EPOCH[920/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05607207]), 'recall': array([0.18276285]), 'ndcg': array([0.15539033])}
# EPOCH[921/1000] loss0.010-|Sample:0.11|
# EPOCH[922/1000] loss0.010-|Sample:0.10|
# EPOCH[923/1000] loss0.010-|Sample:0.10|
# EPOCH[924/1000] loss0.010-|Sample:0.10|
# EPOCH[925/1000] loss0.010-|Sample:0.10|
# EPOCH[926/1000] loss0.010-|Sample:0.10|
# EPOCH[927/1000] loss0.010-|Sample:0.10|
# EPOCH[928/1000] loss0.010-|Sample:0.10|
# EPOCH[929/1000] loss0.010-|Sample:0.10|
# EPOCH[930/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05617422]), 'recall': array([0.18298356]), 'ndcg': array([0.15578092])}
# EPOCH[931/1000] loss0.010-|Sample:0.10|
# EPOCH[932/1000] loss0.010-|Sample:0.10|
# EPOCH[933/1000] loss0.010-|Sample:0.10|
# EPOCH[934/1000] loss0.010-|Sample:0.10|
# EPOCH[935/1000] loss0.010-|Sample:0.10|
# EPOCH[936/1000] loss0.010-|Sample:0.10|
# EPOCH[937/1000] loss0.010-|Sample:0.10|
# EPOCH[938/1000] loss0.010-|Sample:0.10|
# EPOCH[939/1000] loss0.010-|Sample:0.09|
# EPOCH[940/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05609887]), 'recall': array([0.18305216]), 'ndcg': array([0.15551023])}
# EPOCH[941/1000] loss0.010-|Sample:0.11|
# EPOCH[942/1000] loss0.010-|Sample:0.10|
# EPOCH[943/1000] loss0.010-|Sample:0.10|
# EPOCH[944/1000] loss0.010-|Sample:0.10|
# EPOCH[945/1000] loss0.010-|Sample:0.10|
# EPOCH[946/1000] loss0.010-|Sample:0.12|
# EPOCH[947/1000] loss0.010-|Sample:0.10|
# EPOCH[948/1000] loss0.010-|Sample:0.10|
# EPOCH[949/1000] loss0.010-|Sample:0.10|
# EPOCH[950/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05619265]), 'recall': array([0.18271748]), 'ndcg': array([0.15573198])}
# EPOCH[951/1000] loss0.010-|Sample:0.11|
# EPOCH[952/1000] loss0.010-|Sample:0.10|
# EPOCH[953/1000] loss0.010-|Sample:0.10|
# EPOCH[954/1000] loss0.010-|Sample:0.11|
# EPOCH[955/1000] loss0.010-|Sample:0.10|
# EPOCH[956/1000] loss0.010-|Sample:0.10|
# EPOCH[957/1000] loss0.010-|Sample:0.10|
# EPOCH[958/1000] loss0.010-|Sample:0.10|
# EPOCH[959/1000] loss0.010-|Sample:0.10|
# EPOCH[960/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05625293]), 'recall': array([0.18301096]), 'ndcg': array([0.15578256])}
# EPOCH[961/1000] loss0.010-|Sample:0.12|
# EPOCH[962/1000] loss0.010-|Sample:0.10|
# EPOCH[963/1000] loss0.010-|Sample:0.10|
# EPOCH[964/1000] loss0.010-|Sample:0.09|
# EPOCH[965/1000] loss0.010-|Sample:0.10|
# EPOCH[966/1000] loss0.010-|Sample:0.10|
# EPOCH[967/1000] loss0.010-|Sample:0.10|
# EPOCH[968/1000] loss0.010-|Sample:0.10|
# EPOCH[969/1000] loss0.010-|Sample:0.10|
# EPOCH[970/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05625293]), 'recall': array([0.1832982]), 'ndcg': array([0.15574232])}
# EPOCH[971/1000] loss0.010-|Sample:0.10|
# EPOCH[972/1000] loss0.010-|Sample:0.10|
# EPOCH[973/1000] loss0.010-|Sample:0.10|
# EPOCH[974/1000] loss0.010-|Sample:0.10|
# EPOCH[975/1000] loss0.010-|Sample:0.10|
# EPOCH[976/1000] loss0.010-|Sample:0.10|
# EPOCH[977/1000] loss0.010-|Sample:0.10|
# EPOCH[978/1000] loss0.010-|Sample:0.10|
# EPOCH[979/1000] loss0.010-|Sample:0.10|
# EPOCH[980/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05641202]), 'recall': array([0.18367798]), 'ndcg': array([0.15590942])}
# EPOCH[981/1000] loss0.010-|Sample:0.10|
# EPOCH[982/1000] loss0.010-|Sample:0.10|
# EPOCH[983/1000] loss0.010-|Sample:0.10|
# EPOCH[984/1000] loss0.010-|Sample:0.10|
# EPOCH[985/1000] loss0.010-|Sample:0.09|
# EPOCH[986/1000] loss0.010-|Sample:0.10|
# EPOCH[987/1000] loss0.010-|Sample:0.10|
# EPOCH[988/1000] loss0.010-|Sample:0.10|
# EPOCH[989/1000] loss0.010-|Sample:0.10|
# EPOCH[990/1000] loss0.010-|Sample:0.10|
# [TEST]
# {'precision': array([0.05640699]), 'recall': array([0.18361985]), 'ndcg': array([0.15613886])}
# EPOCH[991/1000] loss0.010-|Sample:0.10|
# EPOCH[992/1000] loss0.010-|Sample:0.10|
# EPOCH[993/1000] loss0.010-|Sample:0.11|
# EPOCH[994/1000] loss0.010-|Sample:0.10|
# EPOCH[995/1000] loss0.010-|Sample:0.10|
# EPOCH[996/1000] loss0.010-|Sample:0.10|
# EPOCH[997/1000] loss0.010-|Sample:0.10|
# EPOCH[998/1000] loss0.010-|Sample:0.10|
# EPOCH[999/1000] loss0.010-|Sample:0.10|
# EPOCH[1000/1000] loss0.010-|Sample:0.10|
